# %%
import json
import numpy as np
from collections import defaultdict
import openai
import re
#csv.field_size_limit(sys.maxsize)

# %%
def save_json(data, filepath=r'new_data.json'):
    with open(filepath, 'w') as fp:
        json.dump(data, fp, indent=4)

# %%
api_key = open("api_key").read()
openai.api_key = api_key

# %%
def call_gpt(messages, model="gpt-3.5-turbo-16k-0613"):
    print(messages)
    completions = openai.ChatCompletion.create(
        model=model,
        messages=messages)
    gpt_response = completions['choices'][0]['message']['content'].strip() 
    return gpt_response

# %%
def merge_sentences(datum_sentences):
    sentence_list = [" ".join(sentence_word_list) for sentence_word_list in datum_sentences] # merge the words into sentences
    paragraph = " ".join(sentence_list)
    return paragraph

# %%
def get_arguments(article):
    messages = [ 
        {
            "role": "system", 
            "content": """
                You are an extraction system that extracts the main characters of a news article.
                The main characters can be any organization, person or location that are heavily involved in the event described by the news article.
                The user will provide you with a news article to extract.
                Reply in the format '[character 1] [character 2]...'
            """
        },
        {
            "role": "user", "content": article
        } 
    ]
    arguments = call_gpt(messages)

# %%
def extract_event(sentence):
    messages = [
        { 
            "role": "system", 
            "content": """
                You are an event extraction system. Your task is to extract only the most important event from news articles. 
                Strictly extract only one event. This event should be the most important event in the article.
                Also extract the category of the event.
                The event and category should be human-readable. 
                Reply in this format: 
                [event - category]
                Do not reply more than a line. The news article will be provided by the user.
            """
        },
        { "role": "system", "name": "example_user", "content": "The article discussed the extensive history of doping in Russia, dating back to the 1983 Soviet Union's detailed instructions to inject top athletes with anabolic steroids in order to ensure dominance at the Los Angeles Olympics. Dr. Sergei Portugalov, a key figure in Russia's current doping scandal, was named as the mastermind behind the doping program. The revelations of these schemes led to the banning of Russia's track and field team from the Rio Games, the most severe doping penalty in Olympic history."},
        { "role": "system", "name": "example_system", "content": "Russia's doping scandal - sports scandal"},        
        { "role": "user", "content": sentence}
    ]
    events = call_gpt(messages)
    return events

# %%
def extract_participants(sentence, event):
    messages = [
        { 
            "role": "system", 
            "content": """
                You are a named entity recognition model. You will be given an article and the event recognized in that article by the user.
                The format of the input defining event in article will be:
                [event - category];
                Extract the main participants involved in that event.
                The number of main participants should be 2 or less strictly. 
                Ignore any other participants other than the two main participants.
                Be as concise as possible.
                Reply with the following format:
                [main participant 1],[main participant 2];
            """
        },   
        { "role": "system", "name": "example_user", "content": """
        Article: \n The article discussed the extensive history of doping in Russia, dating back to the 1983 Soviet Union's detailed instructions to inject top athletes with anabolic steroids in order to ensure dominance at the Los Angeles Olympics. Dr. Sergei Portugalov, a key figure in Russia's current doping scandal, was named as the mastermind behind the doping program. The revelations of these schemes led to the banning of Russia's track and field team from the Rio Games, the most severe doping penalty in Olympic history.
        Event: \n [Russia's doping scandal - sports scandal]
        """},
        { "role": "system", "name": "example_system", "content": "[Russia],[Dr. Sergei Portugalov];"},   
        { "role": "user", "content": f"Article: \n {sentence} \n Event: \n {event}".format(sentence, event)},
    ]
    participants = call_gpt(messages)
    return participants

# %%
def merged_all(sentence, event, participants):
    messages = [
        { 
            "role": "system", 
            "content": """
                You will be given an article and the event graph of one event in that article by the user.
                The format of the event graph will be:
                [event - trigger],[main participant 1],[main participant 2];
                Arguments are participants or elements that play specific roles within the context of an event.
                Extract the main arguments and their roles involved in each event.                
                Reply in JSON format with each line being an event in the format:
                [event - trigger],[main participant 1],[main participant 2]:[argument type 1 - argument 1],[argument type 2 - argument 2],...; 
            """
        },   
        { "role": "system", "name": "example_user", "content": "The article discussed the extensive history of doping in Russia, dating back to the 1983 Soviet Union's detailed instructions to inject top athletes with anabolic steroids in order to ensure dominance at the Los Angeles Olympics. Dr. Sergei Portugalov, a key figure in Russia's current doping scandal, was named as the mastermind behind the doping program. The revelations of these schemes led to the banning of Russia's track and field team from the Rio Games, the most severe doping penalty in Olympic history."},
        { "role": "system", "name": "example_system", "content": "[scandal-Russia's current doping scandal]: [Russia],[Dr. Sergei Portugalov]:[country - Russia],[mastermind - Dr. Sergei Portugalov],[affected team - track and field team],[event - Rio Games];\n"},   
        { "role": "user", "content": f"This is the input defining the extracted event and the main participants, strictly use only this event for further tasks  :{cl}"},  
        { "role": "user", "content": f"This is the news article:{sentence}"},
    ]
    events = call_gpt(messages)
    return events

# %%
def summarize_sentence(article, arguments, model="gpt-3.5-turbo-0613"):
    messages = [ 
        {
            "role": "system", 
            "content": """
                You are an summarization system that summarizes the events that happened between the main characters of a news article.
                The user will provide you with a list of main characters and a news article to summarize.
                Try to summarize the article with no more than three sentences. 
                Reply starts with 'The article discussed ...'
            """
        },
        {
            "role": "user", "content": "Main Characters:\n{arguments} \n\n\n Article: {article}".format(arguments=arguments, article=article)
        } 
    ]
    sentence = call_gpt(messages)
    return sentence

# %%
from string import punctuation
def strip_sentence(sentence):
    if sentence.startswith('The article discussed how'):
        stripped_sentence = sentence.replace('The article discussed how', '').strip()
        # stripped_sentence = re.sub(",","",stripped_sentence)
    elif sentence.startswith('The article discussed'):
        stripped_sentence = sentence.replace('The article discussed', '').strip()
        # stripped_sentence = re.sub(",","",stripped_sentence)
    else:
        stripped_sentence = sentence.strip()
    return stripped_sentence
def strip_gpt_response(res):
    return res.strip(punctuation)

# %%
AllTheNews_summarized = json.load(open(r'data/raw/AllTheNews/summarized/2016_10p.json'))
AllTheNews_extracted = json.load(open(r'data/raw/AllTheNews/events/2016_10p_0819.json'))
print(len(AllTheNews_summarized), len(AllTheNews_extracted))

# %%
import string
AllTheNews_summarized = json.load(open(r'data/raw/AllTheNews/summarized/2016_10p.json'))
AllTheNews_extracted = json.load(open(r'data/raw/AllTheNews/events/2016_10p_0819.json'))
extracted_ids = [datum['id'] for datum in AllTheNews_extracted]
error_datum = []
for index, datum in enumerate(AllTheNews_summarized):
    if datum['id'] in extracted_ids: continue
    print('{}/{}: {}'.format(index, len(AllTheNews_summarized), datum['id']))
    sentence = strip_sentence(datum['summary'])
    # gpt 
    event = extract_event(sentence)
    if "\n" in event:
        event = event.split("\n")[0]
    print(event)
    participants = extract_participants(sentence, event).split(",")
    # strip
    stripped = strip_gpt_response(event)
    if len(stripped.split(" - ")) == 1:
        event = stripped  
        event_type = "None"
    else:
        event, event_type = stripped.split(" - ")
    participants = list(map(lambda x: strip_gpt_response(x), participants))
    datum['events'] = {
        "title": event.strip(),
        "type": event_type.strip(),
        "participants": participants
    }
    print("------------------------------------------")
    AllTheNews_extracted.append(datum)
    save_json(AllTheNews_extracted, r'data/raw/AllTheNews//events/2016_10p_0819.json')

# %%
print(len(AllTheNews_summarized), len(AllTheNews_extracted))

# %%
from string import punctuation
def post_process_events(dataset):
    for index, datum in enumerate(dataset):
        datum['doc_id'] = index
        datum['events_raw'] = datum['events']
        events_str = datum['events'].split('\n')
        events = []
        for event_str in events_str:
            arguments=[]
            main_characters = []
            event_str = event_str.strip()
            components = event_str.split(':')
            event_type_raw = components[0].split('-')
            # event_type_p=event_type_raw[0].split('-')
            event_type = event_type_raw[0][1:]
            trigger = event_type_raw[1:2]
            trigger=' '.join([str(elem) for elem in trigger]).strip().strip(punctuation)
            if(trigger==""):
                trigger=event_type
            chars = components[1].split(',')
            # arguments_raw = [arg.strip().strip(punctuation) for arg in components[1:]]
            arguments_raw = components[2:]
            # chars = re.sub(",","",chars)
            for dat in chars:
                dat=re.sub(",","",dat)
                # print(dat)
                main_characters.append(dat)
            for args in arguments_raw:
                # args = re.sub(",","",args)
                temp = args.split('],[')
                for arg in temp:
                    # print(arg)
                    # arg=re.sub(",","",arg)
                    arg_raw=arg.split('-')
                    arg_type=arg_raw[0].strip()
                    # arg_type=re.sub(",","",arg_type)
                    args = arg_raw[1:]
                    args_final=' '.join([str(elem) for elem in args]).strip().strip(punctuation)
                    # args_final=re.sub(",","",args_final)
                    arg_type = str(arg_type).replace('[', '').replace(']', '')
                    arguments.append({arg_type:args_final})
            events.append({'event_type':event_type,'trigger': trigger, 'Main Participants': main_characters, 'Arguments': arguments})
        datum['events'] = events
    return dataset

dataset = json.load(open(r'../All the News/events/merged_test_1.json'))
processed_dataset = post_process_events(dataset)
save_json(processed_dataset, r'../All the News/result/merged_test_1.json')

# %%
# VisPub
import csv
raw_vispub =  csv.DictReader(open('data/raw/VisPub/IEEE VIS papers 1990-2022 - Main dataset-2.csv'))
articles = [article for article in raw_vispub]

# %%
from collections import defaultdict
keyword_count = defaultdict(list)
filtered_articles = []
for index, article in enumerate(articles):
    abstract = article['Abstract']
    keywords = article['AuthorKeywords']
    if abstract == "" or keywords == "": continue
    article['id'] = index
    for keyword in keywords.split(","):
        if keyword == "": continue
        keyword_count[keyword.strip().lower()].append(index) 
    filtered_articles.append(article)
# save_json(filtered_articles, r'data/raw/VisPub/filtered_articles.json')

# %%
print(len(filtered_articles))
# Out:
# 2632

# %%
# filtered_keywords = {k: v for k, v in keyword_count.items() if len(v) > 1}
sorted_keywords = {k: v for k, v in sorted(keyword_count.items(), key=lambda item: len(item[1]))}

# %%
print(len(sorted_keywords))
print(sorted_keywords)
# Out:
# 6043
# {'photosensitive epilepsy': [0], 'photosensitivity': [0], 'federated learning': [1], 'data heterogeneity': [1], 'self-service data transformation': [2], 'programming by example': [2], 'aesthetic pleasure': [3], 'validated scale': [3], 'scale development': [3], 'visual representations': [3], 'neural network architecture search': [4], 'theoretical and empirical research': [5], 'confidence intervals': [6], 'hierarchical tabular data': [7], 'music mood classification': [8], 'physicalization': [9], 'kirigami': [9], 'visual representation design': [9], 'art & graphic design': [9], 'deficit thinking': [11], 'fundamental attribution error': [11], 'correspondence bias': [11], 'equity': [11], 'augmented merge tree': [12], 'beliefs': [14], 'motivated perception': [14], 'tracking & transformation': [15], 'dendrograms': [16], 'cyber-physical networks': [16], 'node-based visualization': [17], 'basketball tracking data': [18], 'off-ball movement analysis': [18], 'high dimensional data visualization': [19], 'parallel coordinates chart': [19], 'user preference': [20], 'takeaways': [20], 'gradient descent': [21], 'uncertainty visualisations': [22], 'missing values': [22], 'data imputation': [22], 'cross-language study': [23], 'icon-arrays': [23], 'natural language understanding': [24], 'semantic inference': [25], 'fragment reassembly': [26], 'iot': [27], 'racket sports': [27], 'sensor data': [27], 'distance measure': [28], 'edit distance': [28], 'concept activation vectors': [30], 'embedded visualization': [31], 'data visualization literacy': [32], 'children': [32], 'constructionism': [32], 'informal learning': [32], 'pedagogy': [34], 'final project': [34], 'game interfaces': [34], 'spatiotemporal dynamics': [35], 'regional industrial structure': [35], 'visualization for machine learning': [36], 'error analysis': [36], 'multi-dimensional exploration': [37], 'embedding projection': [37], 'explicit knowledge generation': [37], 'paper interaction': [38], 'printed data visualization': [38], 'narrative devices': [39], 'structure-borne noise': [40], 'nvh analysis': [40], 'compensation': [41], 'temporal treemaps': [41], 'ergonomic assessment': [42], 'workplace safety': [42], 'dot plot': [43], 'lloyd relaxation': [43], 'kernel frequency estimation': [43], 'non-linear projection': [44], 'contour': [45], 'multiclass visualization': [45], 'color-concept association': [46], 'colorization': [46], 'emd': [46], 'guidance theory': [47], 'guidance implementation': [47], 'visual concept programming': [48], 'data programming': [48], 'self-supervised learning': [48], 'latent space': [49], 'scientific data representation': [49], 'scientometric analysis': [50], 'openalex': [50], 'author affiliation': [50], 'scientific collaboration': [50], 'citation analysis': [50], 'language modeling': [52], 'zero-shot models': [52], 'model understanding': [54], 'reliability diagram': [54], 'benchmark study': [55], 'algorithmic fairness': [56], 'human trafficking': [57], 'infoshield': [57], 'time-frequency': [58], 'webcam': [58], 'multi-attribute data exploration': [59], 'interactive pattern mining': [60], 'comparative visual design': [60], 'path tracing': [61], 'delta tracking': [61], 'colormap data visualizations': [62], 'overdraw': [63], 'overlap-free': [63], 'voronoi decomposition': [65], 'statistical summarization': [65], 'recommendations': [66], 'multi-view coordination': [66], 'historical cohort analysis': [67], 'dynamic mode decomposition': [69], 'spectral decomposition': [69], 'frequency-based constraints': [69], 'situated analytics': [70], 'multiple-view representations': [70], 'view layout': [70], 'data slicing': [71], 'data validation': [71], 'e-commerce': [74], 'promotion strategy': [74], 'time-series prediction': [74], '“what-if” analysis': [74], 'interaction recommendation': [75], 'visualization for public education': [75], 'mixed-initiative exploration': [75], 'quantum computing': [76], 'noise awareness': [76], 'epidemiological modeling': [77], 'human-machine cooper ...

# %%
save_json(sorted_keywords, r'data/raw/VisPub/keywords.json')

# %%
keyword_w_explanation = json.load(open(r'data/raw/VisPub/keywords_w_explanation.json'))
keywords = json.load(open(r'data/raw/VisPub/keywords.json'))
print(len(keyword_w_explanation), len(keywords))
res = {}
for k1, v1 in keyword_w_explanation.items():
    if k1 in keywords:
        res[k1] = v1
save_json(res, r'data/raw/VisPub/keywords_w_explanation_filtered.json')
# Out:
# 1436 1434

# %%
len(res)
# Out:
# 1434

# %%
articles = json.load(open(r'data/raw/VisPub/filtered_articles.json'))
article_dict = {article['id']: article for article in articles}
print(len(sorted_keywords), sorted_keywords)
for keyword, article_ids in sorted_keywords.items():
    for article_id in article_ids:
        if 'keyword' not in article_dict[article_id]: article_dict[article_id]['keyword'] = []
        article_dict[article_id]['keyword'].append(keyword)
save_json(list(article_dict.values()), r'data/raw/VisPub/articles_w_keywords.json')
# Out:
# 1434 {'visual analytics': [4, 5, 27, 36, 37, 55, 56, 68, 96, 100, 102, 117, 138, 140, 149, 152, 154, 157, 175, 193, 197, 204, 226, 228, 243, 245, 246, 256, 261, 280, 290, 299, 301, 307, 308, 317, 326, 328, 331, 335, 350, 354, 364, 369, 372, 375, 386, 387, 402, 403, 406, 410, 420, 421, 435, 438, 439, 441, 443, 448, 464, 474, 483, 484, 486, 488, 489, 490, 493, 497, 511, 518, 519, 521, 522, 525, 528, 549, 555, 564, 582, 605, 612, 619, 620, 639, 642, 645, 650, 654, 655, 656, 662, 663, 664, 665, 666, 667, 668, 673, 678, 681, 688, 709, 724, 726, 728, 731, 740, 746, 753, 873, 874, 875, 885, 888, 891, 905, 909, 923, 929, 961, 977, 983, 989, 991, 1009, 1032, 1041, 1042, 1043, 1048, 1062, 1067, 1069, 1070, 1074, 1087, 1089, 1098, 1099, 1105, 1112, 1116, 1118, 1122, 1125, 1126, 1134, 1139, 1171, 1177, 1181, 1185, 1188, 1205, 1208, 1216, 1221, 1231, 1241, 1246, 1258, 1271, 1279, 1280, 1306, 1320, 1323, 1329, 1332, 1350, 1360, 1401, 1418, 1440, 1472, 1479, 1497, 1498, 1504, 1508, 1511, 1536, 1556, 1590, 1602, 1612, 1616, 1637, 1641, 1726, 1728, 1730, 1732, 1754, 1755, 1776, 1780, 1793, 1830, 1835, 1859, 1884, 1889, 1918, 1921, 1952, 1954, 1972, 1976, 1979, 1981, 1993, 2003, 2020, 2047, 2054, 2061, 2082, 2110, 2120, 2122, 2123, 2127, 2136, 2137, 2140, 2163, 2166, 2171, 2176, 2190, 2196, 2222], 'visualization': [20, 23, 35, 50, 53, 57, 74, 79, 80, 93, 97, 108, 112, 115, 120, 130, 134, 138, 170, 179, 180, 185, 187, 215, 216, 243, 254, 294, 301, 314, 368, 382, 389, 397, 414, 415, 416, 447, 489, 497, 509, 528, 540, 564, 564, 566, 576, 579, 586, 599, 620, 620, 632, 641, 666, 687, 695, 698, 749, 753, 874, 908, 935, 954, 959, 965, 977, 985, 986, 1037, 1050, 1054, 1061, 1066, 1145, 1167, 1180, 1201, 1224, 1225, 1249, 1253, 1264, 1265, 1266, 1280, 1282, 1292, 1295, 1303, 1313, 1343, 1360, 1373, 1412, 1441, 1446, 1470, 1471, 1496, 1510, 1556, 1571, 1603, 1612, 1682, 1691, 1718, 1750, 1755, 1807, 1808, 1833, 1851, 1861, 1884, 1891, 1914, 1953, 1960, 1983, 1984, 2008, 2018, 2021, 2049, 2104, 2121, 2185, 2197, 2201, 2202, 2227, 2239, 2277, 2278, 2296, 2303, 2305, 2320, 2343, 2349, 2361, 2372, 2375, 2385, 2400, 2436, 2480, 2518, 2530, 2531, 2554, 2558, 2564, 2572, 2581, 2607, 2626, 2651, 2656, 2657, 2659, 2671, 2673, 2674, 2679, 2682, 2697, 2703, 2752, 2778, 2790, 2791, 2809, 2819, 2824, 2837, 2842, 2862, 2864, 2871, 2893, 2946, 2977, 3020, 3053, 3054, 3065, 3084, 3085, 3137, 3151, 3182, 3185, 3199, 3250, 3305], 'information visualization': [33, 62, 164, 214, 229, 234, 262, 264, 265, 284, 293, 330, 340, 350, 411, 419, 461, 468, 522, 541, 563, 567, 637, 642, 649, 654, 688, 708, 715, 717, 870, 871, 872, 876, 880, 883, 893, 980, 1034, 1036, 1041, 1043, 1062, 1068, 1079, 1082, 1088, 1096, 1100, 1116, 1125, 1132, 1143, 1164, 1167, 1181, 1184, 1185, 1190, 1194, 1204, 1206, 1227, 1231, 1236, 1272, 1275, 1277, 1294, 1316, 1365, 1402, 1421, 1440, 1506, 1552, 1557, 1562, 1567, 1599, 1620, 1624, 1634, 1641, 1667, 1683, 1690, 1692, 1693, 1700, 1729, 1754, 1762, 1771, 1775, 1786, 1794, 1801, 1831, 1835, 1837, 1843, 1846, 1864, 1867, 1893, 1952, 1954, 1956, 1961, 1969, 1990, 1991, 1994, 2010, 2047, 2085, 2088, 2091, 2096, 2102, 2113, 2116, 2126, 2166, 2171, 2187, 2208, 2215, 2242, 2262, 2265, 2272, 2292, 2300, 2306, 2318, 2322, 2327, 2329, 2330, 2341, 2377, 2386, 2498, 2502, 2511, 2542, 2544, 2545, 2547, 2549, 2555, 2560, 2561, 2581, 2587, 2609, 2637, 2652, 2682, 2704, 2806, 2825, 2880, 2885, 2902, 2942, 2943, 2955, 2960, 2972, 2977, 2995, 3016, 3019, 3024, 3082, 3100, 3119, 3138, 3141, 3142, 3166, 3186, 3202, 3221, 3226, 3243, 3401], 'volume rendering': [61, 168, 312, 358, 476, 623, 628, 638, 703, 737, 959, 963, 1108, 1155, 1207, 1228, 1247, 1253, 1254, 1256, 1328, 1340, 1351, 1358, 1367, 1396, 1429, 1436, 1443, 1473, 1482, 1515, 1584, 1647, 1663, 1701, 1714, 1718, 1724, 1725, 1756, 1778, 1779, 1790, 1839, 1847, 1851, 1870, 1887, 1968, 1975, 2037, 2095, 2097, 2111, 2112, 2124, 2129, 2134, 2139, 2145, 2169, 2205, 2206, 2216, 2255, 2263, 2266, 2277, 2279, 2287, 2291, 2 ...

# %%
article_w_keywords = json.load(open('data/raw/VisPub/articles_w_keywords.json'))
count = 0
for article in article_w_keywords:
    # if article['AuthorKeywords'] == "" or article['Abstract'] == "":
    #     count += 1
    if 'keyword' not in article:
        count += 1
        print(article['id'], article['AuthorKeywords'])
print(count, len(article_w_keywords))
# Out:
# 32 Data visualization literacy,children,constructionism,informal learning
# 34 pedagogy,final project,game interfaces
# 46 Color-concept association,colorization,EMD
# 47 Guidance Theory,Guidance Implementation
# 75 Interaction Recommendation,Visualization for public education,Mixed-initiative Exploration
# 92 High-dimensional filtering,multivariate filtering,output-sensitivity,multivariate attribute queries,progressive culling
# 98 Haptic Feedback,Human Centred Interaction,Robotic Arm
# 105 Pictorial visualization,data-driven design
# 124 accessible visualization,assistive technologies,alternative text for graphics
# 135 Visualization Tools,Visualization Recommendation Algorithms
# 136 Visual causal analysis,urban time series,causal graph analysis
# 156 Data comics,Non-linear narrative,interactive storytelling
# 159 Explanatory Visualisation,Administrative Justice,Law,Law Visualisation
# 183 Disease Progression,State Identification,Sequence Visualization
# 206 Analyzing Counterexamples,Hyperproperties,Multiple Coordinate Views,Explainable Formal Methods
# 239 Bus route planning,spatial decision-making,urban data visual analytics
# 253 Relief shading,shaded relief,hillshade,neural rendering,illustrative visualisation,image-to-image translation
# 272 Statistical communication,comics,scientific reports
# 291 Chart embedding,background embedding,data embedding,chart image,chart reuse
# 305 Astrophysics visualization,agent-based modeling,intergalactic media,Physarum polycephalum,Cosmic Web
# 336 Visualization analytics,Regulatory visualization
# 356 Multi-Robot Systems,Human-Subjects Qualitative Studies,Debugging,I.3.8 [Computer Graphics],Applications
# 378 Geographic / geospatial visualization,remote sensing geology,digital outcrop analysis,integration of spatial and non-spatial data visualization
# 383 visual parameter space exploration,scientific modelling,atmospheric convection
# 400 Automated Infographic Design,Deep Learning-based Approach,Timeline Infographics,Multi-task Model
# 408 Labeled data debugging,trusted item,tSNE
# 409 Deep deformation network,organ meshes,3D / 4D shapes,2D projections,single-view
# 426 Sequence Data,Explainable Artificial Intelligence (XAI),Recurrent Neural Networks (RNNs),Prototype Learning
# 444 Radial charts,time series series data,daily patterns,crowd-sourced experiment
# 465 Natural-language-based Visual Query,Spatial Uncertaity,Trajectory Exploration
# 569 Graph privacy,k-anonymity,structural features,privacy preservation
# 571 Document reading,contextual visualizations,visual aids,comprehension,summarization
# 572 Large Network Exploration,Structure-Based Exploration,Suggestive Exploration
# 610 Astronomy visualization,3D Universe software,star catalog rendering,Gaia mission
# 616 Isocontour visualization,topological uncertainty,marching squares,asymptotic decider,bilinear interpolation,probabilistic computation
# 626 Writing,prewriting,diagraming,content and structure recommendation,pen and touch interfaces
# 631 hexahedral mesh,base complex,sheet decomposition,complexity analysis
# 633 3D volume rendering,bubble visualization,porous media
# 636 Dynamic lighting design,lighting drones
# 661 Outliers,Anomalies
# 692 graph querying,subgraph results,query result visualization
# 720 Developmental disorder,Human Phenotype Ontology (HPO),Phenotypes,Topic models,Topology simplification
# 755 Information visualization;interaction;systems;toolkits;declarative specification
# 756 Deep convolutional neural networks;rectangle packing;matrix reordering;edge bundling;biclustering
# 757 Artificial neural networks;dimensionality reduction;algorithm understanding
# 758 Interactive visualization;machine learning;visual analytics;dimensionality reduction
# 759 Performance analysis;classification;usable machine learning
# 760 augmented reality;Information visualization;data physicalization;ambient displays;ubiquitous computing
# 762 3D Network;Oculus Rift;CAVE;Immersive Analytics;Collaboration
# 763 Visual analytics;guidance model;assistance;user support
# 764 optimal billboard locations;taxi trajectory;visual analytics;comparative analysis
# 765 Visualization Literacy;Assessment Test;Instrument;Measurement;Aptitude;Education
# 766 event sequences;Clickstream Data;sequence mining;visual analytics
# 767 Temporal Data;Marey's Graph;Visual Analytics;Manufacturing;Smart Factory;Connected Industry;Industry 4.0
# 768 Aesthetics in Visualization;Color Perception;Metrics & Benchmarks;Visual Design;Visualization
# 769 Scalability;data cube;multidimensional data;interactive exploration
# 770 Information graphics;visualization;design tools;2D graphics
# 771 Progressive analytics;high dimensional data;iterative refinement;visual analytics
# 772 Topology-based techniques;urban data;visual exploration
# 773 Taxi Trajectories;Taxi Document;Textualization;Name Query;Semantic Interaction;Text Search Engine
# 774 Discussion forum;MOOC;temporal visualization;visual analytics
# 775 cognitive bias;Information visualization;decision-making;decoy effect;attraction effect;asymmetric dominance effect
# 776 information theory;Visual analytics;classification;decision tree;model;facial expression;visualization image
# 777 Parallel coordinates plots;parameter analysis;multi-resolution climate ensembles
# 778 Flow Maps;Matrix Visualisation;Cartographic Information Visualisation
# 779 word embeddings;document visualization
# 780 Visual analysis;decision making;multi-objective optimization;interactive ranking;rank sensitivity
# 781 Visual Data Exploration;Visualization by Demonstration;Visualization Tools
# 782 data video;narrative visualization;data storytelling;authoring tools;visualization systems
# 783 topic modeling;nonnegative matrix factorization;t-distributed stochastic neighbor embedding;magic lens;text analytics
# 785 Narrative visualization;storytelling;annotations;comic strip visualization;time-varying data
# 787 Ensemble visualization;uncertainty visualization;meteorological visualization;iso-contours;time-varying data;clustering
# 788 data analysis;research themes;research topics;taxonomy;visualization history;theory
# 789 axis mapping;interactive model steering;sketch;axis visualization;human-centered visual analytics
# 790 bundling;Network visualization;edge compression;confluent;power graph
# 791 Eye tracking;visual analytics;video visualization
# 792 3D data visualization;Interaction;tactile input;tangible input
# 793 Graph visualization;graph sampling;empirical evaluation
# 794 data cubes;Data modeling;dimensionality reduction;interactive visualization
# 795 Data Quality Assessment;High-Dimensional Data;Hierarchical Aggregation;Linked Views
# 796 text visualization;social media;natural language processing;word cloud;Twitter
# 797 Topological data analysis;multivariate data;data segmentation
# 798 information visualization education;peer learning;toolkit;card;design workshop
# 799 History;Visualization;Interaction
# 800 Game play data visualization;visual knowledge discovery;visual knowledge representation;and game reconstruction
# 801 In situ analysis;rotating stall analysis;Gaussian mixture model;incremental distribution modeling;feature analysis;high performance computing;collaborative development
# 803 Graphical inference;spatial autocorrelation;just noticeable difference;geovisualization;statistical significance
# 804 Shape-changing displays;physicalization;physical visualization;bar charts;user behaviour;data presentation
# 805 illustration;Visualization;iteration
# 806 Design studies;task and requirement analysis;presentation;production;and dissemination;medical visualization
# 807 Name disambiguation;analytical reasoning
# 808 Uncertainty visualization;graph layout;graph visualization;edge bundling;Monte Carlo method
# 809 Geographic visualization;small multiples;whitespace;design space;metrics;optimization
# 810 Visualization framework;data flow;subset flow model;tabular data
# 811 Thematic Maps;Bayesian Surprise;Event Visualization;Spatia-temporal data
# 812 Geographic/Geospatial Visualization;Qualitative Evaluation;Color Perception;Perceptual Cognition
# 814 Machine Learning;Visual Analytics;User Interactions;Analytic Provenance
# 815 trust;transparency;familiarity;uncertainty;biological data analysis
# 817 education;Hierarchies;information visualization
# 818 Externalization user-authored annotation;exploratory sequential data analysis;graph-based visualization
# 819 Exploratory Text Analysis;Knowledge Discovery;Text Visualization
# 820 Ensemble;time-varying;multi-resolution;sensitivity analysis
# 822 Brain Network;Visual Comparison;Hybrid Representation
# 824 Dimension coverage;Tabular data;History;Empirical laboratory study;Exploratory data analysis;Scented widgets
# 826 visual analytics;user-centred design;profiling;constraint programming;tree visualisations
# 827 London tube map;Color;categorical colormap;optimization;seismological data visualization
# 829 scalability;Set visualization;treemaps;interaction
# 830 Matrix Visualization;Visual Quality Measures;Quality Metrics;Feature Detection/Selection;Relational Data
# 831 Medical visualizations;aneurysms;blood flow;wall thickness;wall deformation;projections
# 832 Visual search;laboratory study;eye tracking;map visualization
# 833 View-dependent visualization;focus + context techniques;manipulation and deformation;glyph-based techniques;human-computer interaction
# 834 Atlas;surgical planning;medical visualization
# 835 feature filtering;Feature extraction;heritage preservation;Frangi filter;surface analysis
# 836 Multivariate;Visualization;Real-time;Decal;Surface;Layering;Design
# 837 Cross-sectional cohort analysis;Phenotypes;Human Phenotype Ontology (HPO)
# 838 Glyph-based Techniques;Tensor Field Data;Flow Visualization
# 840 Volume rendering;photon mapping;global illumination;participating media
# 843 Parallel Coordinates;Joint Distribution Reconstruction;Solution Space;High-dimensional Data;Multivariate Data
# 844 Molecular visualization;binding analysis
# 845 Multi-dimensional data;Hybrid visualization
# 846 Theoretical models;human oracle;visual analytics;mixed initiative systems;semantic interaction;sensemaking
# 847 antichain;Hierarchy data;data aggregation;multiscale visualization;tree cut
# 848 Molecular Visualization;Maps;Cartography;Data Aggregation;Dimensionality Reduction;Space-time Cube
# 849 Interactive Exploration;Trend Detection;Time Series
# 851 Eye tracking;gaze visualization;gaze pattern comparison;volumetric medical images;context-embedded interactive scatterplot;interactive temporal chart
# 852 Medical visualization;colon registration;geometry-based techniques;mathematical foundations for visualization
# 853 Choropleth;Classification;Visualization;Geodemographics;Geovisualization
# 854 Visualization of inertial dynamics;N-body systems;magnetism;acceleration
# 855 Volume Rendering;Isosurface;Multidimensional Data
# 856 Volume transformation;Volume visualization;progressive;automatic;parallel;time-varying data;streaming data
# 857 Inertial particles;finite-time Lyapunov exponents;backward integration;preferential particle settling
# 858 GPU-based Data Structures;Binary Index Trees;Sparse Data
# 859 Visualization Models;Integrating Spatial and Non-Spatial Data Visualization;Design Methodologies
# 860 Bioinformatic visualization;education;learning;genome evolution;chromosome;user study
# 861 Illustrative Visualization;Physical Visualization;Interaction;Volume Visualization
# 862 High-content screening;visual analysis;feature selection;image classification;biology;multivariate;hierarchy
# 863 Centralized matching;matching visualization;interaction techniques;visual analytics
# 864 Geometry-based Technique;Spectral Analysis;Biomedical Visualization
# 865 Visual Knowledge Discovery;Temporal Feature Analysis;Radiomics;Spleen;Abdominal Imaging
# 867 Human-Computer Interaction;Quantitative Evaluation and Volume Visualization
# 868 Flow visualization;3D vector fields;Cutting planes;Glyphs;Perception;Evaluation;Human factors
# 878 Graph based visual analytics, Centrality, Taxi trajectories, Urban network, Transportation assessment
# 884 Lo-fidelity prototyping, User-centred design, Sketching for visualization, Ideation
# 892 Weber's law, perception of correlation, log transformation, censored regression, Bayesian methods
# 910 Suggested interactivity, perceived affordances, information visualization for the people, online visualization
# 911 Text highlighting techniques, visual document analytics, text annotation, crowdsourced study
# 1057 Physical Visualizations, Activity Sculptures, Physical Activity, Data Sculptures, Behavioral Change
# 1117 Multi-resolution representations, sparse approximation, pursuit algorithms, large-scale volume rendering
# 1222 WaveletSAT, integral histograms, discrete wavelet transform
# 1298 Informal science education, collaborative learning, large tree visualizations, multi-touch interaction
# 1300 Just-in-time descriptive analytics, feature identification and characterization, point-based visualizations
# 1310 Multi-scale map, web mapping, web cartography, web map projection, web Mercator, HTML5 Canvas
# 1319 Lineups, Visual inference, Power comparison, Efficiency of displays
# 1342 Scatter/gather clustering, alternative clustering, constrained clustering
# 1438 Semantic lenses, magic lenses, graph bundling, attribute filtering
# 1512 Digital collections, archival analysis, visual anaytics, data curation
# 1522 Surface Evolver, bubble-scale simulation, time-dependent visualizations
# 1635 Axis labeling, nice numbers
# 1709 Similan, M&M Measure, Similarity Search, Temporal Categorical Records
# 1731 SUBDTW, trend sequence, trend sequence clustering
# 1734 Information visualization architecture, continuous interaction, multi-threading, layer, preview
# 1751 Information interfaces and presentation, screen design, evaluation / methodology, user / machine systems, software psychology, landscape visualization
# 1768 Intellectual Structure, Paper-reference Matrix, FP-tree, Co-citation
# 1772 Dendrogram, reorderable matrix, compound graphs, data abstraction quality metrics, hierarchical clusters
# 1844 artistic information visualization, interactive information visualization, walk-up-and-use interaction, public displays
# 1850 Color-contrast enhancement, Color-vision deficiency, Recoloring algorithms, Information and Scientific Visualization
# 1869 Interactive visual hypothesis generation, interactive visual exploration and analysis, visualization for climate research
# 1906 Cardiac visualization, coronary artery territories, myocardial perfusion
# 1920 Interior/Exterior Classification, Normal Orientation, Layer Classification, Inside Removal, Graph Cut
# 1974 Multimodal Volume Rendering, Hardware Assisted Raycasting, Surgery Planning
# 1997 Acoustic propagation,Interactive systems
# 2000 DECT image fusion, local surface extraction, Dual Energy CT, metrology, dimensional measurement, variance comparison
# 2009 Tuboids, stream tubes, interactive gpu-centric rendering, neuronal pathways
# 2011 Cardiac MRI, late enhancement, viability, bull's eye plot
# 2023 Visual Analytics Query, Similarity Queries, Interactive Queries
# 2048 Online fantasy sports, tournament, bracket, picks, adaptive tree visualization
# 2056 web 20, JavaScript, scalable vector graphics, visualization components, linked view visual analytics
# 2099 Graphical visualization, interactive information retrieval, faceted metadata
# 2141 Mesh and graph layouts, cache-aware and cache-oblivious layouts, metrics for cache coherence, data locality
# 2179 Book Index, eBooks, Information Scent, contextualization, personalized information access
# 2181 Pipeline model, laziness, functional programming
# 2184 Interactive Detection, Wormhole Attacks, Visualization on Network Security, Wireless Networks, Topology Visualization
# 2194 AJAX, thin-client, SVG, ROC curves, confusion matrices, document categorization
# 2223 visualizing the Web, large network visualization, network sampling
# 2225 skeleton, curve-skeleton
# 2245 cluster-based visualization, sort-last rendering, parallel image compositing
# 2253 Cognitive Walkthrough, usability inspection methods, bibliographic networks
# 2301 intelligent multimodal interfaces, visual context management, automated generation of visualization, visual momentum
# 2308 Cluster Rendering, Sort-Middle, Multi-Projector, Tile Displays, Immediate-Mode Rendering
# 2328 topological fisheye,large graph visualization
# 2340 cross-slits image, multi-perspective image, city block
# 2411 pixel-exact visualization, pixel shaders, spacetime finite elements, discontinuous Galerkin methods
# 2415 Higher Order Elements, Programmable Shaders, Cut-planes
# 2532  X-ray volume rendering, Monte Carlo integration, importance sampling, progressive refinement
# 2579 coastal observatories, environmental observation and forecasting systems, coasts, estuaries, Columbia River
# 2583 Program visualization, Human subjects testing, Visual program languages
# 2584 Psychophysical Scaling, Anesthesia, Patient Vital Sign Monitor
# 2620 radial space-filling hierarchy visualizations, multi-focus distortion, structure-based brushing
# 2669 spectral volume rendering, post-illumination, interactive re-lighting
# 2740 Perceptual color scales, visual artifacts in visualization, Internet color, human color vision
# 2750 Computed Tomography Angiography (CTA), semi automatic segmentation, optimal path computation
# 2755 Temporal Bone Dissection
# 2866 geodesics, visualization features
# 2878 oceanographic visualization, plume, acoustic imaging, centerlines
# 2892 whole field modelling, seabed visualization, sonar technology
# 2922 clothmodeling,wrinklemodeling,deformablemodels
# 3039 Screen-Door Transparency
# 3070 Image Based Rendering, Occlusions
# 3159 Shape representation, image sequence analysis, non-rigid motion, plant biology
# 3410 device unified interface, 3d input device, virtual input device, device information-base
# 210 2632
