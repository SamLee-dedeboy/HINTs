# %%
import networkx as nx
from community import community_louvain
import json
from pybrat.parser import BratParser, Entity, Event, Example, Relation
import matplotlib.pyplot as plt
from pprint import pprint
import numpy as np
from collections import defaultdict

# %%
def read_brat_data(data_path):
    brat = BratParser(error="ignore")
    brat_data = brat.parse(data_path)
    return brat_data

# %%
def brat_data_to_network(data_path):
    G = nx.Graph()
    nodes_dict = {} 
    links = defaultdict(lambda: defaultdict(int))
    doc_count = 0
    argument_num_dict = defaultdict(int)
    for doc in brat_data:
        doc_count += 1
        origin_id_to_new_id_dict = {}
        entity_umls = json.load(open(data_path + doc.id + r'.json'))
#         print(doc.id)
        for entity in doc.entities:
            # TODO: add candidate selection. For now just choosing the first one.
            entity_ui = entity.id # reassign node id to either doc_id + original id or CUI
            if len(entity_umls[entity.id]) != 0: 
                entity_ui = entity_umls[entity.id][0]['ui']
            else:
                # TODO: consider partial matching to disambiguiate entities without CUIs
                entity_ui = doc.id + "-" + entity_ui
            origin_id_to_new_id_dict[entity.id] = entity_ui

            if entity_ui not in nodes_dict.keys():
                nodes_dict[entity_ui] = {
                    "id": entity_ui,
                    "type": "entity",
                    "mentions": [
                        {
                            "doc_id": doc.id, 
                            "mention": entity.mention, 
                            "span": {'start': entity.spans[0].start, 'end': entity.spans[0].end}
#                             "span": entity.spans
                        }
                    ],
                }
            else:
                nodes_dict[entity_ui]["mentions"].append(
                    {
                        "doc_id": doc.id, 
                        "mention": entity.mention, 
                        "span": {'start': entity.spans[0].start, 'end': entity.spans[0].end}


#                         "span": [entity.spans.start, entity.spans.end]
#                         "span": entity.spans
                    }
                )
        # each event is treated as a hyper-edge. 
        # First create a hyper edge node, then connect the hyper edge node with the arguments
        # The node id needs to be independent, but the node type is trigger id 
        for event in doc.events:
            trigger_id = origin_id_to_new_id_dict[event.trigger.id]
            origin_id_to_new_id_dict[event.id] = trigger_id # account for nested events
            argument_ids = list(map(lambda argument: origin_id_to_new_id_dict[argument.id], event.arguments))
            
            sorted_argument_ids = sorted(argument_ids)
            # create hyper edge node
            hyper_edge_node_id = trigger_id + "-" + "-".join(sorted_argument_ids)

            if hyper_edge_node_id not in nodes_dict.keys():
                nodes_dict[hyper_edge_node_id] = {
                    "id": hyper_edge_node_id,
                    "type": "hyper_edge",
                    "trigger": trigger_id,
                    "arguments": sorted_argument_ids,
                    "mentions": [
                        {
                            "doc_id": doc.id, 
                            # TODO: add sentence span
                            # "mention": entity.mention, 
                            # "span": [entity.spans]
                        }
                    ],
                }
            else:
                nodes_dict[hyper_edge_node_id]["mentions"].append(
                    {
                        "doc_id": doc.id,
                        # TODO: add sentence span
                    }
                )

            # add links between hyper edge node and arguments
            for argument_id in argument_ids:
                links[hyper_edge_node_id][argument_id] = 1

            # argument_num_dict[len(argument_ids)].append(trigger_id)
            argument_num_dict[len(argument_ids)] += 1
#                 links.append((trigger_id, argument_id, {'attr': 'someAttr'}))
#         if doc_count == 10: break

    pprint(argument_num_dict)
    # turn overlapping links into link length
    links_as_list = []
    for hyper_edge_node_id, argument_ids in links.items():
        for argument_id in argument_ids.keys():
            links_as_list.append((hyper_edge_node_id, argument_id))
    
    # remove nodes that do not have links
    G.add_nodes_from([(node_id, node_attribute_dict) for node_id, node_attribute_dict in nodes_dict.items()])
    G.add_edges_from(links_as_list)
    
    G.remove_nodes_from(list(n for n in G.nodes() if G.degree(n) == 0))

    print(G.number_of_nodes(), G.number_of_edges())

    return G

# %%
data_path = (r'brat-1.3p1/data/all-brat/')
brat_data = read_brat_data(data_path)
event_network = brat_data_to_network(data_path)
# Out:
# defaultdict(<class 'int'>, {1: 2277, 0: 846, 2: 602, 3: 26, 4: 1})
# 3234 2520

# %%
def draw_network(G):
    # print(G.nodes().data())
    colors = list(map(lambda node: 'blue' if node[1]['type'] == 'entity' else 'black', G.nodes().data()))
    node_sizes = list(map(lambda node: 100+G.degree(node), G.nodes()))
    options = {
        "node_color": colors,
        "node_size": node_sizes,
        "width": 0.5,
        "with_labels": False,
        "pos": nx.spring_layout(G, k=0.15)
    }
    fig = plt.figure(1, figsize=(12, 12), dpi=60)
    nx.draw(G, **options)
    plt.show()

# %%
def plot_degree_distribution(G, fit_line=True):
    degree_sequence = [G.degree(node) for node in G.nodes()]
    degree_counts = [(degree, degree_sequence.count(degree)) for degree in set(degree_sequence)]
    x, y = zip(*degree_counts)
        
    # fit line
    if fit_line:
        filter_degree = 15
        filtered_degree_sequence = list(filter(lambda degree: degree < filter_degree, degree_sequence))
        filtered_degree_counts = [(degree, degree_sequence.count(degree)) for degree in set(filtered_degree_sequence)]
        filtered_x, filtered_y = zip(*filtered_degree_counts)
        log_x = np.log10(filtered_x)
        log_y = np.log10(filtered_y)
        slope, intercept = np.polyfit(log_x, log_y, 1)
        print("slope:", slope, "intercept:", intercept)
        x_vals = np.array([min(filtered_x), max(filtered_x)])
        y_vals = 10**(intercept + slope*np.log10(x_vals))
        plt.plot(x_vals, y_vals, '--')
    
        
    plt.scatter(x, y)
    plt.xscale("log")
    plt.yscale("log")
    plt.xlabel('Degree')
    plt.ylabel('Probability')
    plt.show()

# %%
def get_k_highest_degree_node(G, k=0):
    # get the degree of each node
    degrees = dict(G.degree())
    largest_degrees = sorted(degrees, key=degrees.get, reverse=True)
    # get the data of the k nodes with the largest degree
    data = [G.nodes[node] for node in largest_degrees]
#     for k, node in enumerate(data[:50]):
#         if node['type'] == 'event':
#             print(node['id'], node['type'], degrees[largest_degrees[k]])
#         else:
#             mentions = list(map(lambda mention_data: mention_data['mention'], node['mentions']))
#             print(node['id'], node['type'], degrees[largest_degrees[k]], len(mentions))


        
    print(f"The node with the {k} highest degree is {largest_degrees[k]}, with degree {degrees[largest_degrees[k]]}")
#     pprint(data[k])

# %%
def plot_degree_list_bar(G):
    # parameters
    color_map = {'entity': 'r', 'event': 'b'}
    degrees = dict(G.degree())
    k = 50
    
    # prepare bar data
    # x
    node_list = sorted(degrees, key=degrees.get, reverse=True)[:k]
    for node in node_list:
        node_data = G.nodes[node]
        print(node_data['id'], node_data['type'], G.degree(node))
    # y
    degree_list = [G.degree(node) for node in node_list]
    # color
    type_list = [G.nodes[node]['type'] for node in node_list]
    color_list = [color_map[type] for type in type_list]
    
    # plot
    fig,a = plt.subplots()

    a.bar(node_list, degree_list, color=color_list, edgecolor='white', linewidth=1)
    a.xaxis.set_visible(False)

    # remove x-axis label
#     ax.set(xlabel=None)

    
    # add a legend for the color map
    legend_list = [plt.Rectangle((0,0),1,1,color=color_map[node_type]) for node_type in color_map.keys()]
    plt.legend(legend_list, color_map.keys())


    # show the plot
    plt.show()

# %%
def run_community_detection(G, alg='louvain'):
    if alg == 'louvain':
        return community_louvain.best_partition(G, weight='strength')

# %%
def community_layout(g, partition):
    """
    Compute the layout for a modular graph.


    Arguments:
    ----------
    g -- networkx.Graph or networkx.DiGraph instance
        graph to plot

    partition -- dict mapping int node -> int community
        graph partitions


    Returns:
    --------
    pos -- dict mapping int node -> (float x, float y)
        node positions

    """

    pos_communities = _position_communities(g, partition, scale=3.)

    pos_nodes = _position_nodes(g, partition, scale=1.)

    # combine positions
    pos = dict()
    for node in g.nodes():
        pos[node] = pos_communities[node] + pos_nodes[node]

    return pos

def _position_communities(g, partition, **kwargs):

    # create a weighted graph, in which each node corresponds to a community,
    # and each edge weight to the number of edges between communities
    between_community_edges = _find_between_community_edges(g, partition)

    communities = set(partition.values())
    hypergraph = nx.DiGraph()
    hypergraph.add_nodes_from(communities)
    for (ci, cj), edges in between_community_edges.items():
        hypergraph.add_edge(ci, cj, weight=len(edges))

    # find layout for communities
    pos_communities = nx.spring_layout(hypergraph, **kwargs)

    # set node positions to position of community
    pos = dict()
    for node, community in partition.items():
        pos[node] = pos_communities[community]

    return pos

def _find_between_community_edges(g, partition):

    edges = dict()

    for (ni, nj) in g.edges():
        ci = partition[ni]
        cj = partition[nj]

        if ci != cj:
            try:
                edges[(ci, cj)] += [(ni, nj)]
            except KeyError:
                edges[(ci, cj)] = [(ni, nj)]

    return edges

def _position_nodes(g, partition, **kwargs):
    """
    Positions nodes within communities.
    """

    communities = dict()
    for node, community in partition.items():
        try:
            communities[community] += [node]
        except KeyError:
            communities[community] = [node]

    pos = dict()
    for ci, nodes in communities.items():
        subgraph = g.subgraph(nodes)
        pos_subgraph = nx.spring_layout(subgraph, **kwargs)
        pos.update(pos_subgraph)

    return pos

def visualize_community(G, partition):
    # to install networkx 2.0 compatible version of python-louvain use:
    # pip install -U git+https://github.com/taynaud/python-louvain.git@networkx2
    from community import community_louvain

    partition = community_louvain.best_partition(G)
    pos = community_layout(G, partition)

    fig = plt.figure(1, figsize=(12, 12), dpi=60)
#     pprint(partition)
    nx.draw(G, pos, node_color=list(partition.values()), node_size=40)


    plt.show()
    return

# %%
data_path = (r'brat-1.3p1/data/all-brat/')
brat_data = read_brat_data(data_path)
event_network = brat_data_to_network(data_path)
print(event_network.number_of_nodes(), event_network.number_of_edges())
# pprint(communities)
# Out:
# defaultdict(<class 'int'>, {1: 2277, 0: 846, 2: 602, 3: 26, 4: 1})
# 3234 2520
# 3234 2520

# %%
# filter out events that only occur once
# filtered_nodes = [n for n in event_network.nodes() if event_network.nodes[n]['type']=='entity']
# filtered_nodes = [event_network.nodes[n]['type'] for n in event_network.nodes()]


filtered_nodes = [n for n in event_network.nodes() if event_network.nodes[n]['type']=='hyper_edge' and event_network.degree(n) <= 1]
# pprint(filtered_nodes)
# filtered_nodes = [n for n in event_network.nodes() if event_network.degree(n) <= 1]
event_network.remove_nodes_from(filtered_nodes)
event_network.remove_nodes_from([n for n in event_network.nodes() if event_network.degree(n) == 0])

print(event_network.number_of_nodes(), event_network.number_of_edges())


# draw_network(event_network)
# plot_degree_distribution(event_network)
# plot_degree_list_bar(event_network)
# communities = run_community_detection(event_network)

# visualize_community(event_network, communities)
# get_k_highest_degree_node(event_network, 5)
# Out:
# 868 1013

# %%
def save_json(data, filepath=r'new_data.json'):
    with open(filepath, 'w') as fp:
        json.dump(data, fp, indent=4)
event_network_data = nx.node_link_data(event_network)
pprint(event_network_data)
save_json(event_network_data, r'event_network_data.json')
# Out:
# {'directed': False,
#  'graph': {},
#  'links': [{'source': 'C0718617', 'target': 'C1880177-C0042765-C0718617'},
#            {'source': 'C0718617', 'target': 'C4296939-C0042765-C0718617'},
#            {'source': 'C0718617', 'target': 'C0851285-C0718617-C1430105'},
#            {'source': 'C0718617',
#             'target': 'C0851285-C0718617-PMC1475658-03-Discussion-03-T18'},
#            {'source': 'C3714514', 'target': 'C3245501-C1449385-C3714514'},
#            {'source': 'C3714514', 'target': 'C5240713-C0175697-C3714514'},
#            {'source': 'C3714514', 'target': 'C5240713-C0034579-C3714514'},
#            {'source': 'C3714514', 'target': 'C3245501-C0175697-C3714514'},
#            {'source': 'C3714514',
#             'target': 'C0035820-C3714514-PMC2358977-03-Discussion-T14'},
#            {'source': 'C3714514', 'target': 'C0455242-C0205339-C3714514'},
#            {'source': 'C3714514',
#             'target': 'PMC2593050-00-TIAB-T38-C0033268-C3714514'},
#            {'source': 'C3714514',
#             'target': 'PMC2593050-01-INTRODUCTION-T58-C0033268-C3714514'},
#            {'source': 'C3714514', 'target': 'C1545588-C0205339-C3714514'},
#            {'source': 'C3714514',
#             'target': 'PMC2593050-03-RESULTS-06-T28-C0020835-C3714514'},
#            {'source': 'C3714514',
#             'target': 'PMC2593050-03-RESULTS-06-T28-C0020852-C3714514'},
#            {'source': 'C3714514', 'target': 'C3245501-C0969563-C3714514'},
#            {'source': 'C3714514', 'target': 'C3245501-C1429451-C3714514'},
#            {'source': 'C0042765', 'target': 'C1880177-C0042765-C0718617'},
#            {'source': 'C0042765', 'target': 'C4296939-C0042765-C0718617'},
#            {'source': 'C0042765', 'target': 'C3245501-C0042765-C1449385'},
#            {'source': 'C0042765', 'target': 'C0525045-C0042765-C1441654'},
#            {'source': 'C0042765', 'target': 'C0035820-C0042765-C1429451'},
#            {'source': 'C0042765',
#             'target': 'C0726639-C0042765-PMC2242835-03-Discussion-T28'},
#            {'source': 'C0042765', 'target': 'C0237668-C0042765-C1429451'},
#            {'source': 'C0042765',
#             'target': 'C1314939-C0042765-PMC2266911-02-Results_and_Discussion-01-01-T58'},
#            {'source': 'C0042765',
#             'target': 'C1314939-C0042765-PMC2266911-02-Results_and_Discussion-01-01-T61'},
#            {'source': 'C0042765',
#             'target': 'C1314939-C0042765-PMC2266911-02-Results_and_Discussion-01-01-T64'},
#            {'source': 'C0042765',
#             'target': 'C1159366-C0042765-PMC2266911-02-Results_and_Discussion-01-02-01-T4'},
#            {'source': 'C0042765', 'target': 'C2587213-C0042765-C1870620'},
#            {'source': 'C0042765',
#             'target': 'C0205224-C0042765-PMC2266911-02-Results_and_Discussion-02-04-T2'},
#            {'source': 'C0042765',
#             'target': 'C0332281-C0042765-PMC2266911-02-Results_and_Discussion-02-04-T10'},
#            {'source': 'C0042765', 'target': 'C0001721-C0042765-C0205263'},
#            {'source': 'C0042765',
#             'target': 'C0035820-C0042765-PMC2358977-02-Results-04-T2'},
#            {'source': 'C0042765',
#             'target': 'C0035820-C0042765-PMC2358977-02-Results-04-T13'},
#            {'source': 'C0042765',
#             'target': 'C2587213-C0042765-PMC2358977-03-Discussion-T43'},
#            {'source': 'C0042765', 'target': 'C4054723-C0042765-C1827066'},
#            {'source': 'C0042765', 'target': 'C4684213-C0042765-C1827066'},
#            {'source': 'C0042765',
#             'target': 'C3898777-C0042765-PMC2593050-00-TIAB-T1'},
#            {'source': 'C0042765',
#             'target': 'C2095534-C0042765-PMC2593050-00-TIAB-T3'},
#            {'source': 'C0042765',
#             'target': 'C3898777-C0042765-PMC2593050-00-TIAB-T21'},
#            {'source': 'C0042765',
#             'target': 'C2095534-C0042765-PMC2593050-01-INTRODUCTION-T28'},
#            {'source': 'C0042765',
#             'target': 'C3898777-C0042765-PMC2593050-04-DISCUSSION-T14'},
#            {'source': 'C0042765',
#             'target': 'C2095534-C0042765-PMC2593050-04-DISCUSSION-T15'},
#            {'source': 'C0042765', 'target': 'C1280500-C0042765-C1433342'},
#            {'source': 'C0042765', 'target': 'C0035820-C0042765-C1433342'},
#            {'source': 'C0042765', 'target': 'C3245501-C0042765-C1433342'},
#            {'source': 'C0042765', 'target': 'C1159366-C0042765-C0768768'},
#            {'source': 'C0042765', 'target': 'C0851827-C0042765-C0768768'},
#            {'source': 'C0042765', 'target': 'C1280500-C0042765-C0674722'},
#            {'source': 'C0042765', 'target': 'C1280500-C0042765-C1739675'},
#            {'source': 'C0042765', 'target': 'C0522506-C0042765-C1739675'},
#            {'source': 'C0042765', 'target': 'C0205224-C0042765-C0255025'},
#            {'source': 'C0042765', 'target': 'C0360504-C0042765-C0255025'},
#            {'source': 'C0042765', 'target': 'C0360504-C0042765-C0967543'},
#            {'source': 'C0042765', 'target': 'C0205224-C0042765-C0967543'},
#            {'source': 'C0042765', 'target': 'C3245501-C0042765-C1739675'},
#            {'source': 'C0042765', 'target': 'C1314939-C0042765-C1739675'},
#            {'source': 'C0042765', 'target': 'C3263269-C0042765-C2001849'},
#            {'source': 'C0042765', 'target': 'C3263269-C0042765-C4483126'},
#            {'source': 'C0042765', 'target': 'C3245501-C0042765-C0255025'},
#            {'source': 'C0042765', 'target': 'C3245501-C0042765-C0967543'},
#            {'source': 'C0042765', 'target': 'C1280500-C0042765-C1623416'},
#            {'source': 'C0042765',
#             'target': 'C5240713-C0042765-PMC2714965-01-Introduction-T23'},
#            {'source': 'C0042765', 'target': 'C1314939-C0042765-C1429451'},
#            {'source': 'C0042765', 'target': 'C3245501-C0042765-C4559850'},
#            {'source': 'C0042765', 'target': 'C3245501-C0042765-C3663567'},
#            {'source': 'C0042765',
#             'target': 'C0035820-C0042765-PMC2856668-01-Introduction-T47'},
#            {'source': 'C0042765',
#             'target': 'C0205224-C0042765-PMC2858072-00-TIAB-T6'},
#            {'source': 'C0042765',
#             'target': 'PMC2858072-01-Introduction-T44-C0042765-PMC2858072-01-Introduction-T15'},
#            {'source': 'C0042765',
#             'target': 'PMC2858072-02-Results_and_Discussion-03-T116-C0042765-C0664254'},
#            {'source': 'C0042765',
#             'target': 'PMC2858072-02-Results_and_Discussion-03-T116-C0042765-C1741620'},
#            {'source': 'C0042765',
#             'target': 'PMC2858072-02-Results_and_Discussion-03-T116-C0042765-PMC2858072-02-Results_and_Discussion-03-T18'},
#            {'source': 'C0042765',
#             'target': 'C2587213-C0042765-PMC2858072-02-Results_and_Discussion-03-T28'},
#            {'source': 'C0042765',
#             'target': 'C2587213-C0042765-PMC2858072-02-Results_and_Discussion-03-T30'},
#            {'source': 'C0042765', 'target': 'C0332281-C0042765-C1174336'},
#            {'source': 'C0042765',
#             'target': 'C3245501-C0042765-PMC2858072-02-Results_and_Discussion-04-T40'},
#            {'source': 'C0042765', 'target': 'C3245501-C0042765-C1062752'},
#            {'source': 'C0042765',
#             'target': 'C3245501-C0042765-PMC2858072-02-Results_and_Discussion-04-T44'},
#            {'source': 'C0544461', 'target': 'C3840428-C0205217-C0544461'},
#            {'source': 'C0544461', 'target': 'C1254595-C0205217-C0544461'},
#            {'source': 'C0544461', 'target': 'C0001721-C0185023-C0544461'},
#            {'source': 'C3659907', 'target': 'C0851827-C0185117-C3659907'},
#            {'source': 'C0102137', 'target': 'C0205263-C0102137-C0185117'},
#            {'source': 'C1141646', 'target': 'C2954564-C1141646-C1701700'},
#            {'source': 'C1430105', 'target': 'C0851285-C0718617-C1430105'},
#            {'source': 'C0657653', 'target': 'C1302275-C0657653-C1302275'},
#            {'source': 'C0657653', 'target': 'C1302275-C0185117-C0657653'},
#            {'source': 'C0657653', 'target': 'C0205217-C0657653-C1302275'},
#            {'source': 'C0657653', 'target': 'C0205217-C0185117-C0657653'},
#            {'source': 'C0657653', 'target': 'C0425256-C0185117-C0657653'},
#            {'source': 'C0851285', 'target': 'C0851827-C0053697-C0851285'},
#            {'source': 'C0185117', 'target': 'C1302275-C0185117-C0657653'},
#            {'source': 'C0185117', 'target': 'C0205217-C0185117-C0657653'},
#            {'source': 'C0185117', 'target': 'C0851285-C0185117-C0294175'},
#            {'source': 'C0185117', 'target': 'C0851827-C0185117-C3659907'},
#            {'source': 'C0185117', 'target': 'C0425256-C0185117-C0657653'},
#            {'source': 'C0185117',
#             'target': 'C0425256-C0185117-PMC1475658-03-Discussion-03-T6'},
#            {'source': 'C0185117', 'target': 'C0151526-C0185117-C1429451'},
#            {'source': 'C0185117', 'target': 'C0557450-C0185117-C1172332'},
#            {'source': 'C0185117', 'target': 'C0851827-C0185117-C1172332'},
#            {'source': 'C0185117', 'target': 'C1280500-C0185117-C1441654'},
#            {'source': 'C0185117', 'target': 'C0383704-C0185117-C0961725'},
#            {'source': 'C0185117', 'target': 'C0033373-C0185117-C0961725'},
#            {'source': 'C0185117', 'target': 'C5451107-C0185117-C1441654'},
#            {'source': 'C0185117', 'target': 'C0301630-C0185117-C0531454'},
#            {'source': 'C0185117', 'target': 'C0851827-C0185117-C1431905'},
#            {'source': 'C0185117',
#             'target': 'C0851827-C0185117-PMC1874608-03-RESULTS-02-T24'},
#            {'source': 'C0185117', 'target': 'C1159366-C0185117-C0531454'},
#            {'source': 'C0185117', 'target': 'C1159366-C0185117-C1257144'},
#            {'source': 'C0185117', 'target': 'C0151526-C0185117-C1431904'},
#            {'source': 'C0185117', 'target': 'C0151526-C0185117-C1431905'},
#            {'source': 'C0185117', 'target': 'C0360504-C0185117-C1441654'},
#            {'source': 'C0185117', 'target': 'C0151526-C0185117-C1441654'},
#            {'source': 'C0185117', 'target': 'C1537373-C0185117-C1441654'},
#            {'source': 'C0185117', 'target': 'C1879547-C0185117-C1431905'},
#            {'source': 'C0185117', 'target': 'C1879547-C0185117-C0531454'},
#            {'source': 'C0185117',
#             'target': 'C0442808-C0185117-PMC1874608-03-RESULTS-03-T64'},
#            {'source': 'C0185117', 'target': 'C0392756-C0185117-C0961725'},
#            {'source': 'C0185117', 'target': 'C0518469-C0185117-C1441654'},
#            {'source': 'C0185117',
#             'target': 'C1879547-C0185117-PMC1874608-04-DISCUSSION-T61'},
#            {'source': 'C0185117',
#             'target': 'C0205217-C0185117-PMC1874608-04-DISCUSSION-T103'},
#            {'source': 'C0185117',
#             'target': 'C0001721-C0185117-PMC1874608-04-DISCUSSION-T121'},
#            {'source': 'C0185117',
#             'target': 'C0518469-C0185117-PMC1974823-01-Introduction-T31'},
#            {'source': 'C0185117', 'target': 'C3271242-C0185117-C0916739'},
#            {'source': 'C0185117', 'target': 'C0851827-C0185117-C0916739'},
#            {'source': 'C0185117', 'target': 'C0518469-C0185117-C1145667'},
#            {'source': 'C0185117', 'target': 'C1280500-C0185117-C0916739'},
#            {'source': 'C0185117',
#             'target': 'C3245501-C0185117-PMC1974823-03-Results-01-T30'},
#            {'source': 'C0185117', 'target': 'C0086597-C0185117-C0916739'},
#            {'source': 'C0185117', 'target': 'C0851285-C0185117-C0916739'},
#            {'source': 'C0185117',
#             'target': 'PMC1974823-03-Results-03-T68-C0185117-C1145667'},
#            {'source': 'C0185117',
#             'target': 'C0035820-C0185117-PMC1974823-04-Discussion-T4'},
#            {'source': 'C0185117', 'target': 'C1879547-C0185117-C0916739'},
#            {'source': 'C0185117', 'target': 'C2587213-C0185117-C0916739'},
#            {'source': 'C0185117', 'target': 'C0851285-C0037420-C0185117'},
#            {'source': 'C0185117', 'target': 'C0851285-C0185117-C1429451'},
#            {'source': 'C0185117', 'target': 'C0851827-C0185117-C1431735'},
#            {'source': 'C0185117',
#             'target': 'C2587213-C0185117-PMC2266911-02-Results_and_Discussion-01-03-T27'},
#            {'source': 'C0185117',
#             'target': 'PMC2430206-01-Background-T29-C0185117-PMC2430206-01-Background-T11'},
#            {'source': 'C0185117', 'target': 'C0525045-C0185117-C1704492'},
#            {'source': 'C0185117', 'target': 'C0205263-C0185117-C1429451'},
#            {'source': 'C0185117', 'target': 'C0205263-C0185117-C1429861'},
#            {'source': 'C0185117', 'target': 'C0376366-C0185117-C2286466'},
#            {'source': 'C0185117',
#             'target': 'PMC2581603-02-Results-06-T39-C0185117-C2286466'},
#            {'source': 'C0185117',
#             'target': 'PMC2581603-02-Results-06-T39-C0185117-C5543850'},
#            {'source': 'C0185117',
#             'target': 'PMC2581603-02-Results-06-T39-C0185117-C2669106'},
#            {'source': 'C0185117',
#             'target': 'PMC2581603-02-Results-06-T39-C0185117-C3771099'},
#            {'source': 'C0185117', 'target': 'C0376366-C0185117-C5543850'},
#            {'source': 'C0185117', 'target': 'C0376366-C0185117-C2669106'},
#            {'source': 'C0185117', 'target': 'C0376366-C0185117-C3771099'},
#            {'source': 'C0185117', 'target': 'C3840428-C0185117-C0683598'},
#            {'source': 'C0185117', 'target': 'C0205263-C0102137-C0185117'},
#            {'source': 'C0185117', 'target': 'C0205224-C0185117-C1433342'},
#            {'source': 'C0185117', 'target': 'C3536597-C0185117-C0768768'},
#            {'source': 'C0185117', 'target': 'C0522506-C0185117-C1739675'},
#            {'source': 'C0185117', 'target': 'C0851285-C0185117-C0255025'},
#            {'source': 'C0185117', 'target': 'C1159366-C0185117-C1429451'},
#            {'source': 'C0185117', 'target': 'C1159366-C0185117-C1437563'},
#            {'source': 'C0185117', 'target': 'C0851827-C0185117-C1257195'},
#            {'source': 'C0185117', 'target': 'C1708517-C0185117-C0768768'},
#            {'source': 'C0185117',
#             'target': 'PMC2816692-02-Results-01-T43-C0185117-C0768768'},
#            {'source': 'C0185117',
#             'target': 'C0700114-C0185117-PMC2816692-03-Discussion-03-T9'},
#            {'source': 'C0185117',
#             'target': 'C2587213-C0185117-PMC2856668-00-TIAB-T16'},
#            {'source': 'C0185117',
#             'target': 'C0851285-C0185117-PMC2856668-04-Discussion-T5'},
#            {'source': 'C0185117',
#             'target': 'C2587213-C0185117-PMC2856668-04-Discussion-T12'},
#            {'source': 'C0185117',
#             'target': 'C2587213-C0185117-PMC2856668-04-Discussion-T136'},
#            {'source': 'C0185117',
#             'target': 'C0851827-C0185117-PMC2858072-02-Results_and_Discussion-03-T32'},
#            {'source': 'C0185117',
#             'target': 'C0700589-C0185117-PMC2858072-02-Results_and_Discussion-03-T77'},
#            {'source': 'C0294175', 'target': 'C0851285-C0185117-C0294175'},
#            {'source': 'C1302275', 'target': 'C1302275-C0657653-C1302275'},
#            {'source': 'C1302275', 'target': 'C0205217-C0657653-C1302275'},
#            {'source': 'C1302275', 'target': 'C1302275-C1302275-C1419948'},
#            {'source': 'C0205217', 'target': 'C3840428-C0205217-C0544461'},
#            {'source': 'C0205217', 'target': 'C1254595-C0205217-C0544461'},
#            {'source': 'C1327616', 'target': 'C2587213-C1327616-C1429451'},
#            {'source': 'C1327616', 'target': 'C0851827-C1327616-C1429451'},
#            {'source': 'C1327616',
#             'target': 'C0205224-C1327616-PMC2242835-02-Results-06-T53'},
#            {'source': 'C1327616', 'target': 'C0205224-C1327616-C4548191'},
#            {'source': 'C1327616',
#             'target': 'C0205224-C1327616-PMC2242835-02-Results-06-T55'},
#            {'source': 'C1327616',
#             'target': 'C0205224-C1327616-PMC2242835-03-Discussion-T76'},
#            {'source': 'C1327616',
#             'target': 'C0205224-C1327616-PMC2242835-03-Discussion-T77'},
#            {'source': 'C1327616', 'target': 'C0237668-C1327616-C1429451'},
#            {'source': 'C0683598', 'target': 'C3245501-C0683598-C1449385'},
#            {'source': 'C0683598',
#             'target': 'C3245501-C0683598-PMC1804205-02-Results-05-T5'},
#            {'source': 'C0683598', 'target': 'C0851827-C0683598-C1429861'},
#            {'source': 'C0683598',
#             'target': 'C0851285-C0683598-PMC2430206-01-Background-T19'},
#            {'source': 'C0683598', 'target': 'C0215848-C0683598-C1172332'},
#            {'source': 'C0683598',
#             'target': 'C0215848-C0683598-PMC2581603-01-Introduction-T42'},
#            {'source': 'C0683598',
#             'target': 'C3245501-C0683598-PMC2581603-02-Results-07-T28'},
#            {'source': 'C0683598', 'target': 'C3840428-C0185117-C0683598'},
#            {'source': 'C0683598',
#             'target': 'C0851827-C0683598-PMC2581603-03-Discussion-T37'},
#            {'source': 'C0683598', 'target': 'C0205224-C0683598-C0969563'},
#            {'source': 'C0683598', 'target': 'C2349975-C0250225-C0683598'},
#            {'source': 'C0205263', 'target': 'C0001721-C0042765-C0205263'},
#            {'source': 'C0017262',
#             'target': 'C2587213-C0017262-PMC1974823-00-TIAB-T9'},
#            {'source': 'C0017262', 'target': 'C4062695-C0017262-C1433342'},
#            {'source': 'C0017262', 'target': 'C0700114-C0017262-C1701700'},
#            {'source': 'PMC1475658-03-Discussion-03-T6',
#             'target': 'C0425256-C0185117-PMC1475658-03-Discussion-03-T6'},
#            {'source': 'PMC1475658-03-Discussion-03-T18',
#             'target': 'C0851285-C0718617-PMC1475658-03-Discussion-03-T18'},
#            {'source': 'C0003537', 'target': 'C3536597-C0003537-C0768768'},
#            {'source': 'C1429861', 'target': 'C1879547-C1429861-C1449385'},
#            {'source': 'C1429861', 'target': 'C1553423-C1429861-C1449385'},
#            {'source': 'C1429861', 'target': 'C1879547-C1429861-C1437563'},
#            {'source': 'C1429861', 'target': 'C1145667-C0255766-C1429861'},
#            {'source': 'C1429861', 'target': 'C1159366-C1429861-C1569547'},
#            {'source': 'C1429861', 'target': 'C1159366-C1429861-C1722214'},
#            {'source': 'C1429861', 'target': 'C5240713-C1429861-C1449385'},
#            {'source': 'C1429861',
#             'target': 'C1145667-C0086860-C1429861-C1569547'},
#            {'source': 'C1429861', 'target': 'C1879547-C0255766-C1429861'},
#            {'source': 'C1429861', 'target': 'C3245501-C1429861-C1449385'},
#            {'source': 'C1429861', 'target': 'C0851827-C0683598-C1429861'},
#            {'source': 'C1429861', 'target': 'C1879547-C1429861-C1569547'},
#            {'source': 'C1429861',
#             'target': 'C1145667-C1429861-PMC2581603-01-Introduction-T49'},
#            {'source': 'C1429861', 'target': 'C0205263-C0185117-C1429861'},
#            {'source': 'C1449385', 'target': 'C1879547-C1429861-C1449385'},
#            {'source': 'C1449385', 'target': 'C1879547-C1449385-C1479218'},
#            {'source': 'C1449385', 'target': 'C1879547-C1449385-C3964964'},
#            {'source': 'C1449385', 'target': 'C1553423-C1429861-C1449385'},
#            {'source': 'C1449385', 'target': 'C1553423-C1449385-C1479218'},
#            {'source': 'C1449385', 'target': 'C1553423-C1449385-C3964964'},
#            {'source': 'C1449385', 'target': 'C3245501-C0042765-C1449385'},
#            {'source': 'C1449385', 'target': 'C3245501-C1449385-C3714514'},
#            {'source': 'C1449385', 'target': 'C3245501-C0683598-C1449385'},
#            {'source': 'C1449385', 'target': 'C5240713-C1429861-C1449385'},
#            {'source': 'C1449385', 'target': 'C3245501-C1429861-C1449385'},
#            {'source': 'C1449385', 'target': 'C1879547-C1449385-C1569547'},
#            {'source': 'C1479218', 'target': 'C1879547-C1449385-C1479218'},
#            {'source': 'C1479218', 'target': 'C1553423-C1449385-C1479218'},
#            {'source': 'C3964964', 'target': 'C1879547-C1449385-C3964964'},
#            {'source': 'C3964964', 'target': 'C1553423-C1449385-C3964964'},
#            {'source': 'C0255766', 'target': 'C1145667-C0255766-C1429861'},
#            {'source': 'C0255766', 'target': 'C1879547-C0255766-C1429861'},
#            {'source': 'C0255766', 'target': 'C1879547-C0255766-C1429451'},
#            {'source': 'C0175697', 'target': 'C5240713-C0175697-C3714514'},
#            {'source': 'C0175697', 'target': 'C3245501-C0175697-C3714514'},
#            {'source': 'C0175697', 'target': 'C1145667-C0175697-C2286466'},
#            {'source': 'C0175697', 'target': 'C1145667-C0175697-C5543850'},
#            {'source': 'C2286466', 'target': 'C3250033-C1437563-C2286466'},
#            {'source': 'C2286466',
#             'target': 'C3250033-C2286466-PMC1804205-03-Discussion-T58'},
#            {'source': 'C2286466', 'target': 'C1879547-C1429451-C2286466'},
#            {'source': 'C2286466', 'target': 'C1145667-C0175697-C2286466'},
#            {'source': 'C2286466', 'target': 'C0376366-C0185117-C2286466'},
#            {'source': 'C2286466', 'target': 'C1145667-C1437563-C2286466'},
#            {'source': 'C2286466', 'target': 'C0376366-C1437563-C2286466'},
#            {'source': 'C2286466',
#             'target': 'PMC2581603-02-Results-06-T39-C0185117-C2286466'},
#            {'source': 'C2286466', 'target': 'C0376366-C0857127-C2286466'},
#            {'source': 'C1437563', 'target': 'C1879547-C1429861-C1437563'},
#            {'source': 'C1437563', 'target': 'C3250033-C1437563-C2286466'},
#            {'source': 'C1437563', 'target': 'C1145667-C1437563-C2286466'},
#            {'source': 'C1437563', 'target': 'C1145667-C1437563-C5543850'},
#            {'source': 'C1437563', 'target': 'C0376366-C1437563-C2286466'},
#            {'source': 'C1437563', 'target': 'C0376366-C1437563-C5543850'},
#            {'source': 'C1437563', 'target': 'C1159366-C0185117-C1437563'},
#            {'source': 'C1429451', 'target': 'C1879547-C0255766-C1429451'},
#            {'source': 'C1429451', 'target': 'C0151526-C0185117-C1429451'},
#            {'source': 'C1429451', 'target': 'C1879547-C1429451-C2286466'},
#            {'source': 'C1429451', 'target': 'C2587213-C1327616-C1429451'},
#            {'source': 'C1429451', 'target': 'C0035820-C0042765-C1429451'},
#            {'source': 'C1429451',
#             'target': 'C1159366-C1429451-PMC2242835-02-Results-06-T64'},
#            {'source': 'C1429451',
#             'target': 'C1159366-C1429451-PMC2242835-02-Results-06-T65'},
#            {'source': 'C1429451', 'target': 'C0851827-C1327616-C1429451'},
#            {'source': 'C1429451', 'target': 'C1159366-C1429451-C1429662'},
#            {'source': 'C1429451',
#             'target': 'C1159366-C1429451-PMC2242835-03-Discussion-T56'},
#            {'source': 'C1429451',
#             'target': 'C1159366-C1429451-PMC2242835-03-Discussion-T57'},
#            {'source': 'C1429451', 'target': 'C0851285-C0185117-C1429451'},
#            {'source': 'C1429451', 'target': 'C0237668-C1327616-C1429451'},
#            {'source': 'C1429451', 'target': 'C0237668-C0042765-C1429451'},
#            {'source': 'C1429451',
#             'target': 'C1145667-C1429451-PMC2581603-01-Introduction-T49'},
#            {'source': 'C1429451', 'target': 'C0205263-C0185117-C1429451'},
#            {'source': 'C1429451',
#             'target': 'C1145667-C1429451-PMC2639726-02-Results-07-T14'},
#            {'source': 'C1429451', 'target': 'C1879547-C1158770-C1429451'},
#            {'source': 'C1429451', 'target': 'C1159366-C0185117-C1429451'},
#            {'source': 'C1429451', 'target': 'C1314939-C0042765-C1429451'},
#            {'source': 'C1429451', 'target': 'C1159366-C0297551-C1429451'},
#            {'source': 'C1429451', 'target': 'C3245501-C1429451-C3714514'},
#            {'source': 'C1145667', 'target': 'C0518469-C0185117-C1145667'},
#            {'source': 'C1145667',
#             'target': 'PMC1974823-03-Results-03-T68-C0185117-C1145667'},
#            {'source': 'C1145667', 'target': 'C0035820-C0031715-C1145667'},
#            {'source': 'C1145667', 'target': 'C1280500-C0031715-C1145667'},
#            {'source': 'C1145667', 'target': 'C0554988-C1145667-C5226623'},
#            {'source': 'C1145667', 'target': 'C0554988-C0768768-C1145667'},
#            {'source': 'C1327142', 'target': 'C0851827-C0220669-C1327142'},
#            {'source': 'C1569547', 'target': 'C1159366-C1429861-C1569547'},
#            {'source': 'C1569547',
#             'target': 'C1145667-C0086860-C1429861-C1569547'},
#            {'source': 'C1569547', 'target': 'C1879547-C1429861-C1569547'},
#            {'source': 'C1569547', 'target': 'C1879547-C1449385-C1569547'},
#            {'source': 'C1722214', 'target': 'C1159366-C1429861-C1722214'},
#            {'source': 'C0383704', 'target': 'C0033373-C0383704-C0961725'},
#            {'source': 'C0857127', 'target': 'C0376366-C0857127-C2286466'},
#            {'source': 'C0040649', 'target': 'C1879547-C0040649-C1431905'},
#            {'source': 'C0040649', 'target': 'C1879547-C0040649-C0531454'},
#            {'source': 'C0040649', 'target': 'C4743777-C0040649-C0916739'},
#            {'source': 'C0040649',
#             'target': 'C2587213-C0040649-PMC2856668-00-TIAB-T16'},
#            {'source': 'C0040649',
#             'target': 'C3898777-C0040649-PMC2856668-01-Introduction-T37'},
#            {'source': 'C0040649',
#             'target': 'C2587213-C0040649-PMC2856668-04-Discussion-T12'},
#            {'source': 'C0040649',
#             'target': 'C2587213-C0040649-PMC2856668-04-Discussion-T136'},
#            {'source': 'C0040649',
#             'target': 'C0518469-C0040649-PMC2858072-01-Introduction-T30'},
#            {'source': 'C0040649',
#             'target': 'C2587213-C0040649-PMC2858072-02-Results_and_Discussion-01-T46'},
#            {'source': 'C0040649', 'target': 'C2587213-C0040649-C1174335'},
#            {'source': 'C0040649',
#             'target': 'C0700589-C0040649-PMC2858072-02-Results_and_Discussion-03-T39'},
#            {'source': 'C0040649', 'target': 'C0851827-C0040649-C0664254'},
#            {'source': 'C0031715', 'target': 'C0035820-C0031715-C1145667'},
#            {'source': 'C0031715', 'target': 'C1879547-C0031715-C0916739'},
#            {'source': 'C0031715', 'target': 'C1280500-C0031715-C1145667'},
#            {'source': 'C0031715', 'target': 'C3536597-C0031715-C0768768'},
#            {'source': 'C0031715',
#             'target': 'C0522506-C0031715-PMC2774163-02-Results-02-T33'},
#            {'source': 'C0031715', 'target': 'C0360504-C0031715-C1701700'},
#            {'source': 'C0031715', 'target': 'C0443264-C0031715-C1701700'},
#            {'source': 'C0031715',
#             'target': 'PMC2774163-03-Discussion-T154-C0031715-C1701700'},
#            {'source': 'C0086860',
#             'target': 'C1145667-C0086860-C1429861-C1569547'},
#            {'source': 'C0086860', 'target': 'C1145667-C0086860-C1441654'},
#            {'source': 'C0086860',
#             'target': 'C1145667-C0086860-C0916739-C1451978'},
#            {'source': 'C0086860',
#             'target': 'C0439855-C0086860-C3001658-PMC1974823-03-Results-03-T29'},
#            {'source': 'C0086860',
#             'target': 'C0037420-C0086860-C3001658-PMC1974823-03-Results-03-T34'},
#            {'source': 'C0086860', 'target': 'C1159366-C0086860-C3001658'},
#            {'source': 'C0086860',
#             'target': 'C1145667-C0086860-C0768768-C5226344'},
#            {'source': 'C5226623',
#             'target': 'C1145667-C5226623-PMC2639726-02-Results-07-T12'},
#            {'source': 'C5226623', 'target': 'C1879547-C0768768-C5226623'},
#            {'source': 'C5226623',
#             'target': 'C1145667-C5226344-C5226623-C5672738'},
#            {'source': 'C5226623', 'target': 'C0554988-C1145667-C5226623'},
#            {'source': 'C1172332', 'target': 'C0557450-C0185117-C1172332'},
#            {'source': 'C1172332', 'target': 'C0851827-C0185117-C1172332'},
#            {'source': 'C1172332',
#             'target': 'C1159366-C1172332-PMC2581603-00-TIAB-T9'},
#            {'source': 'C1172332', 'target': 'C0215848-C0683598-C1172332'},
#            {'source': 'C1172332', 'target': 'C3250033-C0024467-C1172332'},
#            {'source': 'C0454277', 'target': 'C1292856-C0454277-C1744314'},
#            {'source': 'C0454277', 'target': 'C1292856-C0454277-C2976703'},
#            {'source': 'PMC1804205-02-Results-05-T5',
#             'target': 'C3245501-C0683598-PMC1804205-02-Results-05-T5'},
#            {'source': 'C1333696', 'target': 'C3250033-C0074995-C1333696'},
#            {'source': 'C1437584', 'target': 'C1553423-C1437584-C1741620'},
#            {'source': 'C0074995', 'target': 'C3250033-C0074995-C1333696'},
#            {'source': 'PMC1804205-03-Discussion-T58',
#             'target': 'C3250033-C2286466-PMC1804205-03-Discussion-T58'},
#            {'source': 'C1441654', 'target': 'C0443264-C0961725-C1441654'},
#            {'source': 'C1441654', 'target': 'C0376366-C1412751-C1441654'},
#            {'source': 'C1441654', 'target': 'C1280500-C0185117-C1441654'},
#            {'source': 'C1441654', 'target': 'C0525045-C0042765-C1441654'},
#            {'source': 'C1441654', 'target': 'C5451107-C0185117-C1441654'},
#            {'source': 'C1441654', 'target': 'C0360504-C0185117-C1441654'},
#            {'source': 'C1441654', 'target': 'C5451107-C0961725-C1441654'},
#            {'source': 'C1441654', 'target': 'C0151526-C0185117-C1441654'},
#            {'source': 'C1441654', 'target': 'C1537373-C0185117-C1441654'},
#            {'source': 'C1441654', 'target': 'C0383704-C0961725-C1441654'},
#            {'source': 'C1441654', 'target': 'C1145667-C0086860-C1441654'},
#            {'source': 'C1441654', 'target': 'C1145667-C0961725-C1441654'},
#            {'source': 'C1441654', 'target': 'C0518469-C0185117-C1441654'},
#            {'source': 'C0961725', 'target': 'C0443264-C0961725-C1441654'},
#            {'source': 'C0961725', 'target': 'C3250072-C0961725-C1431905'},
#            {'source': 'C0961725', 'target': 'C0383704-C0961725-C1431905'},
#            {'source': 'C0961725', 'target': 'C0033373-C0961725-C1431905'},
#            {'source': 'C0961725', 'target': 'C0383704-C0185117-C0961725'},
#            {'source': 'C0961725', 'target': 'C0383704-C0033373-C0961725'},
#            {'source': 'C0961725', 'target': 'C0033373-C0383704-C0961725'},
#            {'source': 'C0961725', 'target': 'C0033373-C0185117-C0961725'},
#            {'source': 'C0961725', 'target': 'C5451107-C0961725-C1441654'},
#            {'source': 'C0961725', 'target': 'C0383704-C0961725-C1441654'},
#            {'source': 'C0961725', 'target': 'C1145667-C0961725-C1441654'},
#            {'source': 'C0961725', 'target': 'C0392756-C0185117-C0961725'},
#            {'source': 'C1431905',
#             'target': 'C1145667-C1431905-PMC1874608-01-INTRODUCTION-T45'},
#            {'source': 'C1431905', 'target': 'C3250072-C0961725-C1431905'},
#            {'source': 'C1431905', 'target': 'C0383704-C0961725-C1431905'},
#            {'source': 'C1431905', 'target': 'C0033373-C0961725-C1431905'},
#            {'source': 'C1431905', 'target': 'C0851827-C0185117-C1431905'},
#            {'source': 'C1431905', 'target': 'C0151526-C0185117-C1431905'},
#            {'source': 'C1431905', 'target': 'C1879547-C0040649-C1431905'},
#            {'source': 'C1431905', 'target': 'C1879547-C0185117-C1431905'},
#            {'source': 'C1431905', 'target': 'C1145667-C0531454-C1431905'},
#            {'source': 'C1431905',
#             'target': 'C1145667-C1431905-PMC1874608-04-DISCUSSION-T10'},
#            {'source': 'C0531454', 'target': 'C1145667-C0531454-C1257040'},
#            {'source': 'C0531454', 'target': 'C1145667-C0531454-C1257144'},
#            {'source': 'C0531454',
#             'target': 'C1145667-C0531454-C1431904-PMC1874608-01-INTRODUCTION-T45'},
#            {'source': 'C0531454',
#             'target': 'C1145667-C0531454-PMC1874608-01-INTRODUCTION-T45'},
#            {'source': 'C0531454', 'target': 'C0301630-C0185117-C0531454'},
#            {'source': 'C0531454', 'target': 'C1159366-C0185117-C0531454'},
#            {'source': 'C0531454', 'target': 'C1879547-C0040649-C0531454'},
#            {'source': 'C0531454', 'target': 'C1879547-C0185117-C0531454'},
#            {'source': 'C0531454', 'target': 'C1145667-C0531454-C1431905'},
#            {'source': 'C1257144', 'target': 'C1145667-C0531454-C1257144'},
#            {'source': 'C1257144', 'target': 'C1159366-C0185117-C1257144'},
#            {'source': 'C1412751', 'target': 'C0376366-C1412751-C1441654'},
#            {'source': 'C5672738',
#             'target': 'C1145667-C0916739-C3001658-C5672738'},
#            {'source': 'C5672738',
#             'target': 'C1145667-C0916739-C5672738-PMC1974823-01-Introduction-T29'},
#            {'source': 'C5672738', 'target': 'C1145667-C3001658-C5672738'},
#            {'source': 'C5672738',
#             'target': 'C1145667-C1451978-C5672738-PMC1974823-03-Results-03-T43'},
#            {'source': 'C5672738',
#             'target': 'C0037420-C0916739-C1451978-C5672738'},
#            {'source': 'C5672738',
#             'target': 'C1450344-C1741620-C5672738-PMC1976333-02-Results-Discussion-12-T24'},
#            {'source': 'C5672738',
#             'target': 'C1145667-C0244036-C1433342-C5672738-PMC2605554-01-Introduction-T25'},
#            {'source': 'C5672738',
#             'target': 'C1145667-C5226344-C5226623-C5672738'},
#            {'source': 'C5672738',
#             'target': 'C1145667-C0038568-C0768768-C5672738'},
#            {'source': 'C5672738',
#             'target': 'C1145667-C1453882-C3773040-C5672738'},
#            {'source': 'C0037420',
#             'target': 'C2053429-C0037420-PMC1974823-01-Introduction-T72'},
#            {'source': 'C0037420', 'target': 'C0851285-C0037420-C0185117'},
#            {'source': 'C0037420', 'target': 'C0443264-C0037420-C0721374'},
#            {'source': 'C0030054', 'target': 'C0037420-C0030054-C0721374'},
#            {'source': 'C0030054', 'target': 'C0037420-C0030054-C2742851'},
#            {'source': 'C1431904',
#             'target': 'C1145667-C1431904-PMC1874608-01-INTRODUCTION-T45'},
#            {'source': 'C1431904',
#             'target': 'C1145667-C0531454-C1431904-PMC1874608-01-INTRODUCTION-T45'},
#            {'source': 'C1431904', 'target': 'C0151526-C0185117-C1431904'},
#            {'source': 'C1257040', 'target': 'C1145667-C0531454-C1257040'},
#            {'source': 'PMC1874608-01-INTRODUCTION-T45',
#             'target': 'C1145667-C1431904-PMC1874608-01-INTRODUCTION-T45'},
#            {'source': 'PMC1874608-01-INTRODUCTION-T45',
#             'target': 'C1145667-C0531454-C1431904-PMC1874608-01-INTRODUCTION-T45'},
#            {'source': 'PMC1874608-01-INTRODUCTION-T45',
#             'target': 'C1145667-C1431905-PMC1874608-01-INTRODUCTION-T45'},
#            {'source': 'PMC1874608-01-INTRODUCTION-T45',
#             'target': 'C1145667-C0531454-PMC1874608-01-INTRODUCTION-T45'},
#            {'source': 'C1741620',
#             'target': 'C1450344-C1741620-C5672738-PMC1976333-02-Results-Discussion-12-T24'},
#            {'source': 'C1741620',
#             'target': 'C1145667-C1741620-PMC2639726-02-Results-07-T9'},
#            {'source': 'C1741620', 'target': 'C1553423-C1437584-C1741620'},
#            {'source': 'C1741620',
#             'target': 'PMC2858072-02-Results_and_Discussion-03-T116-C0042765-C1741620'},
#            {'source': 'C3824251',
#             'target': 'C1145667-C3824251-PMC2639726-03-Discussion-03-T41'},
#            {'source': 'C0162809',
#             'target': 'C1145667-C0162809-PMC2639726-03-Discussion-03-T41'},
#            {'source': 'C0033373', 'target': 'C0383704-C0033373-C0961725'},
#            {'source': 'PMC1874608-03-RESULTS-02-T24',
#             'target': 'C0851827-C0185117-PMC1874608-03-RESULTS-02-T24'},
#            {'source': 'PMC1874608-03-RESULTS-03-T64',
#             'target': 'C0442808-C0185117-PMC1874608-03-RESULTS-03-T64'},
#            {'source': 'C1158770', 'target': 'C1879547-C1158770-C1429451'},
#            {'source': 'PMC1874608-04-DISCUSSION-T10',
#             'target': 'C1145667-C1431905-PMC1874608-04-DISCUSSION-T10'},
#            {'source': 'PMC1874608-04-DISCUSSION-T61',
#             'target': 'C1879547-C0185117-PMC1874608-04-DISCUSSION-T61'},
#            {'source': 'PMC1874608-04-DISCUSSION-T103',
#             'target': 'C0205217-C0185117-PMC1874608-04-DISCUSSION-T103'},
#            {'source': 'C1429459',
#             'target': 'C1145667-C1429459-C4742986-PMC1874608-04-DISCUSSION-T113'},
#            {'source': 'C1429459',
#             'target': 'PMC2652828-02-Results_and_Discussion-05-04-T73-C0255025-C1429459'},
#            {'source': 'C1429459',
#             'target': 'PMC2652828-02-Results_and_Discussion-05-04-T74-C0255025-C1429459'},
#            {'source': 'C4742986',
#             'target': 'C1145667-C1429459-C4742986-PMC1874608-04-DISCUSSION-T113'},
#            {'source': 'PMC1874608-04-DISCUSSION-T113',
#             'target': 'C1145667-C1429459-C4742986-PMC1874608-04-DISCUSSION-T113'},
#            {'source': 'PMC1874608-04-DISCUSSION-T121',
#             'target': 'C0001721-C0185117-PMC1874608-04-DISCUSSION-T121'},
#            {'source': 'C0033268', 'target': 'C0851827-C0033268-C1431735'},
#            {'source': 'C0033268',
#             'target': 'PMC2593050-00-TIAB-T38-C0033268-C3714514'},
#            {'source': 'C0033268',
#             'target': 'PMC2593050-01-INTRODUCTION-T58-C0033268-C3714514'},
#            {'source': 'C0033268', 'target': 'C5240713-C0033268-C1433342'},
#            {'source': 'C1149789', 'target': 'C0376366-C1149789-C4507377'},
#            {'source': 'C1149789', 'target': 'C1145667-C1149789-C1419209'},
#            {'source': 'C0004482', 'target': 'C1145667-C0004482-C0969563'},
#            {'source': 'C0004482', 'target': 'C4703332-C0004482-C0969563'},
#            {'source': 'C0004482', 'target': 'C0851827-C0004482-C0969563'},
#            {'source': 'C0004482', 'target': 'C0332281-C0004482-C0969563'},
#            {'source': 'C0004482', 'target': 'C1145667-C0004482-C0961154'},
#            {'source': 'C0004482', 'target': 'C0332297-C0004482-C0969563'},
#            {'source': 'C0004482',
#             'target': 'C1145667-C0004482-PMC2816692-02-Results-04-T7'},
#            {'source': 'C0004482',
#             'target': 'C1145667-C0004482-C1149341-PMC2856668-04-Discussion-T38'},
#            {'source': 'C1433342', 'target': 'C4062695-C0017262-C1433342'},
#            {'source': 'C1433342', 'target': 'C0205224-C0185117-C1433342'},
#            {'source': 'C1433342',
#             'target': 'C1145667-C0244036-C1433342-C5672738-PMC2605554-01-Introduction-T25'},
#            {'source': 'C1433342', 'target': 'C1280500-C0042765-C1433342'},
#            {'source': 'C1433342', 'target': 'C0035820-C0042765-C1433342'},
#            {'source': 'C1433342', 'target': 'C3245501-C0042765-C1433342'},
#            {'source': 'C1433342', 'target': 'C5240713-C0033268-C1433342'},
#            {'source': 'C1955824',
#             'target': 'PMC1913099-02-Results-Discussion-08-T29-C1955824-PMC1913099-02-Results-Discussion-08-T24'},
#            {'source': 'C1955824',
#             'target': 'PMC1913099-02-Results-Discussion-08-T29-C1955824-PMC1913099-02-Results-Discussion-08-T25'},
#            {'source': 'PMC1913099-02-Results-Discussion-08-T24',
#             'target': 'PMC1913099-02-Results-Discussion-08-T29-C1955824-PMC1913099-02-Results-Discussion-08-T24'},
#            {'source': 'PMC1913099-02-Results-Discussion-08-T25',
#             'target': 'PMC1913099-02-Results-Discussion-08-T29-C1955824-PMC1913099-02-Results-Discussion-08-T25'},
#            {'source': 'PMC1913099-02-Results-Discussion-10-T10',
#             'target': 'C0392752-C0230927-PMC1913099-02-Results-Discussion-10-T10'},
#            {'source': 'PMC1913099-02-Results-Discussion-10-T11',
#             'target': 'C0392752-C0230927-PMC1913099-02-Results-Discussion-10-T11'},
#            {'source': 'C0230927',
#             'target': 'C0392752-C0230927-PMC1913099-02-Results-Discussion-10-T10'},
#            {'source': 'C0230927',
#             'target': 'C0392752-C0230927-PMC1913099-02-Results-Discussion-10-T11'},
#            {'source': 'C1422345', 'target': 'C0376366-C1422345-C4507377'},
#            {'source': 'C0916739', 'target': 'C4062777-C0916739-C1505298'},
#            {'source': 'C0916739',
#             'target': 'C1145667-C0916739-C3001658-C5672738'},
#            {'source': 'C0916739',
#             'target': 'C1145667-C0086860-C0916739-C1451978'},
#            {'source': 'C0916739',
#             'target': 'C1145667-C0916739-C5672738-PMC1974823-01-Introduction-T29'},
#            {'source': 'C0916739', 'target': 'C3271242-C0185117-C0916739'},
#            {'source': 'C0916739', 'target': 'C0851827-C0185117-C0916739'},
#            {'source': 'C0916739', 'target': 'C1280500-C0185117-C0916739'},
#            {'source': 'C0916739', 'target': 'C1879547-C0916739-C1451978'},
#            {'source': 'C0916739', 'target': 'C0086597-C0185117-C0916739'},
#            {'source': 'C0916739', 'target': 'C0851285-C0185117-C0916739'},
#            {'source': 'C0916739', 'target': 'C4743777-C0040649-C0916739'},
#            {'source': 'C0916739',
#             'target': 'C0037420-C0916739-C1451978-C5672738'},
#            {'source': 'C0916739',
#             'target': 'C1145667-C0916739-C3001658-PMC1974823-04-Discussion-T60'},
#            {'source': 'C0916739', 'target': 'C1879547-C0185117-C0916739'},
#            {'source': 'C0916739', 'target': 'C2587213-C0185117-C0916739'},
#            {'source': 'C0916739', 'target': 'C1879547-C0031715-C0916739'},
#            {'source': 'C1505298', 'target': 'C4062777-C0916739-C1505298'},
#            {'source': 'C1451978',
#             'target': 'C1145667-C0086860-C0916739-C1451978'},
#            {'source': 'C1451978',
#             'target': 'C2587213-C1451978-PMC1974823-03-Results-01-T4'},
#            {'source': 'C1451978', 'target': 'C1879547-C0916739-C1451978'},
#            {'source': 'C1451978',
#             'target': 'C1145667-C1451978-C5672738-PMC1974823-03-Results-03-T43'},
#            {'source': 'C1451978',
#             'target': 'C0037420-C0916739-C1451978-C5672738'},
#            {'source': 'PMC1974823-00-TIAB-T9',
#             'target': 'C2587213-C0017262-PMC1974823-00-TIAB-T9'},
#            {'source': 'C5301858', 'target': 'C0037420-C1431954-C5301858'},
#            {'source': 'C0968261',
#             'target': 'PMC1974823-01-Introduction-T72-C0348055-C0968261'},
#            {'source': 'C3001658',
#             'target': 'C1145667-C0916739-C3001658-C5672738'},
#            {'source': 'C3001658',
#             'target': 'C0439855-C0086860-C3001658-PMC1974823-03-Results-03-T29'},
#            {'source': 'C3001658',
#             'target': 'C0037420-C0086860-C3001658-PMC1974823-03-Results-03-T34'},
#            {'source': 'C3001658', 'target': 'C1145667-C3001658-C5672738'},
#            {'source': 'C3001658',
#             'target': 'C3271242-C3001658-PMC1974823-04-Discussion-T15'},
#            {'source': 'C3001658',
#             'target': 'C1145667-C0916739-C3001658-PMC1974823-04-Discussion-T60'},
#            {'source': 'C3001658',
#             'target': 'C0311403-C3001658-PMC1974823-04-Discussion-T62'},
#            {'source': 'C3001658', 'target': 'C1159366-C0086860-C3001658'},
#            {'source': 'PMC1974823-01-Introduction-T29',
#             'target': 'C1145667-C0916739-C5672738-PMC1974823-01-Introduction-T29'},
#            {'source': 'PMC1974823-01-Introduction-T31',
#             'target': 'C0518469-C0185117-PMC1974823-01-Introduction-T31'},
#            {'source': 'C0348055',
#             'target': 'PMC1974823-01-Introduction-T72-C0348055-C0968261'},
#            {'source': 'C1431954', 'target': 'C0037420-C1431954-C5301858'},
#            {'source': 'PMC1974823-01-Introduction-T72',
#             'target': 'C2053429-C0037420-PMC1974823-01-Introduction-T72'},
#            {'source': 'PMC1974823-03-Results-01-T4',
#             'target': 'C2587213-C1451978-PMC1974823-03-Results-01-T4'},
#            {'source': 'PMC1974823-03-Results-01-T30',
#             'target': 'C3245501-C0185117-PMC1974823-03-Results-01-T30'},
#            {'source': 'PMC1974823-03-Results-03-T29',
#             'target': 'C0439855-C0086860-C3001658-PMC1974823-03-Results-03-T29'},
#            {'source': 'PMC1974823-03-Results-03-T34',
#             'target': 'C0037420-C0086860-C3001658-PMC1974823-03-Results-03-T34'},
#            {'source': 'PMC1974823-03-Results-03-T43',
#             'target': 'C1145667-C1451978-C5672738-PMC1974823-03-Results-03-T43'},
#            {'source': 'PMC1974823-04-Discussion-T4',
#             'target': 'C0035820-C0185117-PMC1974823-04-Discussion-T4'},
#            {'source': 'PMC1974823-04-Discussion-T15',
#             'target': 'C3271242-C3001658-PMC1974823-04-Discussion-T15'},
#            {'source': 'C4507377', 'target': 'C0376366-C1504637-C4507377'},
#            {'source': 'C4507377', 'target': 'C0376366-C4507377-C5197502'},
#            {'source': 'C4507377', 'target': 'C0376366-C1422345-C4507377'},
#            {'source': 'C4507377', 'target': 'C0376366-C1149789-C4507377'},
#            {'source': 'C4507377', 'target': 'C0035143-C0037231-C4507377'},
#            {'source': 'PMC1974823-04-Discussion-T60',
#             'target': 'C1145667-C0916739-C3001658-PMC1974823-04-Discussion-T60'},
#            {'source': 'PMC1974823-04-Discussion-T62',
#             'target': 'C0311403-C3001658-PMC1974823-04-Discussion-T62'},
#            {'source': 'C0618319',
#             'target': 'C1145667-C0618319-PMC1976333-02-Results-Discussion-03-T11'},
#            {'source': 'PMC1976333-02-Results-Discussion-03-T11',
#             'target': 'C1145667-C0618319-PMC1976333-02-Results-Discussion-03-T11'},
#            {'source': 'C0034579', 'target': 'C5240713-C0034579-C3714514'},
#            {'source': 'C0008039', 'target': 'C3853838-C0008039-C0656135'},
#            {'source': 'C0656135', 'target': 'C3853838-C0008039-C0656135'},
#            {'source': 'C0962034',
#             'target': 'C1145667-C0053697-C0385732-C0962034'},
#            {'source': 'C0962034', 'target': 'C1145667-C0385732-C0962034'},
#            {'source': 'C0962034', 'target': 'C1145667-C0053697-C0962034'},
#            {'source': 'C0053697', 'target': 'C1145667-C0053697-C0385732'},
#            {'source': 'C0053697',
#             'target': 'C1145667-C0053697-C0385732-C0962034'},
#            {'source': 'C0053697', 'target': 'C1145667-C0053697-C0962034'},
#            {'source': 'C0053697', 'target': 'C0851827-C0053697-C0851285'},
#            {'source': 'C0385732', 'target': 'C1145667-C0053697-C0385732'},
#            {'source': 'C0385732',
#             'target': 'C1145667-C0053697-C0385732-C0962034'},
#            {'source': 'C0385732', 'target': 'C1145667-C0385732-C0962034'},
#            {'source': 'C0243125', 'target': 'C0243125-C0243125-C1568028'},
#            {'source': 'PMC1976333-02-Results-Discussion-12-T24',
#             'target': 'C1450344-C1741620-C5672738-PMC1976333-02-Results-Discussion-12-T24'},
#            {'source': 'C1744314', 'target': 'C1145667-C1744314-C2976703'},
#            {'source': 'C1744314', 'target': 'C1292856-C0454277-C1744314'},
#            {'source': 'C2976703', 'target': 'C1145667-C1744314-C2976703'},
#            {'source': 'C2976703', 'target': 'C1292856-C0454277-C2976703'},
#            {'source': 'PMC2242835-02-Results-06-T53',
#             'target': 'C0205224-C1327616-PMC2242835-02-Results-06-T53'},
#            {'source': 'C4548191', 'target': 'C0205224-C1327616-C4548191'},
#            {'source': 'PMC2242835-02-Results-06-T55',
#             'target': 'C0205224-C1327616-PMC2242835-02-Results-06-T55'},
#            {'source': 'PMC2242835-02-Results-06-T64',
#             'target': 'C1159366-C1429451-PMC2242835-02-Results-06-T64'},
#            {'source': 'PMC2242835-02-Results-06-T65',
#             'target': 'C1159366-C1429451-PMC2242835-02-Results-06-T65'},
#            {'source': 'C0024467', 'target': 'C3250033-C0024467-C1172332'},
#            {'source': 'PMC2242835-03-Discussion-T28',
#             'target': 'C0726639-C0042765-PMC2242835-03-Discussion-T28'},
#            {'source': 'C1429662', 'target': 'C1159366-C1429451-C1429662'},
#            {'source': 'PMC2242835-03-Discussion-T56',
#             'target': 'C1159366-C1429451-PMC2242835-03-Discussion-T56'},
#            {'source': 'PMC2242835-03-Discussion-T57',
#             'target': 'C1159366-C1429451-PMC2242835-03-Discussion-T57'},
#            {'source': 'PMC2242835-03-Discussion-T76',
#             'target': 'C0205224-C1327616-PMC2242835-03-Discussion-T76'},
# ...
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 215, 'start': 210}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 370, 'start': 365}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 406, 'start': 401}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 455, 'start': 450}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 1025, 'start': 1020}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 1097, 'start': 1092}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 1218, 'start': 1213}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 1282, 'start': 1277}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 1398, 'start': 1393}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 1671, 'start': 1666}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 1740, 'start': 1735}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 1877, 'start': 1872}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 2118, 'start': 2113}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'semac',
#                           'span': {'end': 2451, 'start': 2446}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'semac',
#                           'span': {'end': 2630, 'start': 2625}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 2694, 'start': 2689}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 2776, 'start': 2771}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'SeMac',
#                           'span': {'end': 2880, 'start': 2875}}],
#             'type': 'entity'},
#            {'id': 'C0453947',
#             'mentions': [{'doc_id': 'PMC2885601-00-TIAB',
#                           'mention': 'Mac',
#                           'span': {'end': 153, 'start': 150}},
#                          {'doc_id': 'PMC2885601-00-TIAB',
#                           'mention': 'Mac',
#                           'span': {'end': 521, 'start': 518}},
#                          {'doc_id': 'PMC2885601-01-INTRODUCTION',
#                           'mention': 'Mac',
#                           'span': {'end': 1114, 'start': 1111}},
#                          {'doc_id': 'PMC2885601-01-INTRODUCTION',
#                           'mention': 'Mac',
#                           'span': {'end': 1364, 'start': 1361}},
#                          {'doc_id': 'PMC2885601-01-INTRODUCTION',
#                           'mention': 'Mac',
#                           'span': {'end': 1517, 'start': 1514}},
#                          {'doc_id': 'PMC2885601-01-INTRODUCTION',
#                           'mention': 'Mac',
#                           'span': {'end': 1533, 'start': 1530}},
#                          {'doc_id': 'PMC2885601-01-INTRODUCTION',
#                           'mention': 'Mac',
#                           'span': {'end': 1675, 'start': 1672}},
#                          {'doc_id': 'PMC2885601-01-INTRODUCTION',
#                           'mention': 'Mac',
#                           'span': {'end': 1779, 'start': 1776}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-01',
#                           'mention': 'Mac',
#                           'span': {'end': 20, 'start': 17}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-01',
#                           'mention': 'Mac',
#                           'span': {'end': 54, 'start': 51}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-01',
#                           'mention': 'Mac',
#                           'span': {'end': 137, 'start': 134}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-01',
#                           'mention': 'Mac',
#                           'span': {'end': 260, 'start': 257}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'Mac',
#                           'span': {'end': 73, 'start': 70}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'Mac',
#                           'span': {'end': 275, 'start': 272}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'Mac',
#                           'span': {'end': 1150, 'start': 1147}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'Mac',
#                           'span': {'end': 1361, 'start': 1358}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'Mac',
#                           'span': {'end': 1516, 'start': 1513}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'Mac',
#                           'span': {'end': 1534, 'start': 1531}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'Mac',
#                           'span': {'end': 1617, 'start': 1614}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'Mac',
#                           'span': {'end': 393, 'start': 390}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'Mac',
#                           'span': {'end': 467, 'start': 464}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'Mac',
#                           'span': {'end': 651, 'start': 648}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'Mac',
#                           'span': {'end': 1037, 'start': 1034}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'Mac',
#                           'span': {'end': 1297, 'start': 1294}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'Mac',
#                           'span': {'end': 1766, 'start': 1763}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'Mac',
#                           'span': {'end': 2160, 'start': 2157}}],
#             'type': 'entity'},
#            {'id': 'C0034805',
#             'mentions': [{'doc_id': 'PMC2885601-01-INTRODUCTION',
#                           'mention': 'Fc receptor',
#                           'span': {'end': 1478, 'start': 1467}},
#                          {'doc_id': 'PMC2885601-01-INTRODUCTION',
#                           'mention': 'Fc receptor',
#                           'span': {'end': 1630, 'start': 1619}},
#                          {'doc_id': 'PMC2885601-01-INTRODUCTION',
#                           'mention': 'Fc receptor',
#                           'span': {'end': 1703, 'start': 1692}}],
#             'type': 'entity'},
#            {'arguments': ['C0020852', 'C0034805'],
#             'id': 'C0037420-C0020852-C0034805',
#             'mentions': [{'doc_id': 'PMC2885601-01-INTRODUCTION'}],
#             'trigger': 'C0037420',
#             'type': 'hyper_edge'},
#            {'arguments': ['C0034805', 'C0453947'],
#             'id': 'C1145667-C0034805-C0453947',
#             'mentions': [{'doc_id': 'PMC2885601-01-INTRODUCTION'}],
#             'trigger': 'C1145667',
#             'type': 'hyper_edge'},
#            {'id': 'C0205242',
#             'mentions': [{'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'cleaved',
#                           'span': {'end': 752, 'start': 745}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'cleaved',
#                           'span': {'end': 752, 'start': 745}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'cleaved',
#                           'span': {'end': 1229, 'start': 1222}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'cleaved',
#                           'span': {'end': 1229, 'start': 1222}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'cleaved',
#                           'span': {'end': 1299, 'start': 1292}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'cleaved',
#                           'span': {'end': 1299, 'start': 1292}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'cleaved',
#                           'span': {'end': 1542, 'start': 1535}},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03',
#                           'mention': 'cleaved',
#                           'span': {'end': 1542, 'start': 1535}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'cleaved',
#                           'span': {'end': 1158, 'start': 1151}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'cleaved',
#                           'span': {'end': 1209, 'start': 1202}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'cleaved',
#                           'span': {'end': 1209, 'start': 1202}}],
#             'type': 'entity'},
#            {'arguments': ['C0080178', 'C0453947'],
#             'id': 'C0080178-C0080178-C0453947',
#             'mentions': [{'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION'},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION'}],
#             'trigger': 'C0080178',
#             'type': 'hyper_edge'},
#            {'arguments': ['C0205242', 'C1419948'],
#             'id': 'C0205242-C0205242-C1419948',
#             'mentions': [{'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION'}],
#             'trigger': 'C0205242',
#             'type': 'hyper_edge'},
#            {'arguments': ['C0080178', 'C1419948'],
#             'id': 'C0080178-C0080178-C1419948',
#             'mentions': [{'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION'},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION'},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION'}],
#             'trigger': 'C0080178',
#             'type': 'hyper_edge'},
#            {'arguments': ['C0868946', 'C1419948'],
#             'id': 'C0868946-C0868946-C1419948',
#             'mentions': [{'doc_id': 'PMC2885601-03-RESULTS-03'}],
#             'trigger': 'C0868946',
#             'type': 'hyper_edge'},
#            {'arguments': ['C0453947', 'C0868946'],
#             'id': 'C0868946-C0453947-C0868946',
#             'mentions': [{'doc_id': 'PMC2885601-03-RESULTS-03'}],
#             'trigger': 'C0868946',
#             'type': 'hyper_edge'},
#            {'arguments': ['C0205242', 'C0453947'],
#             'id': 'C0205242-C0205242-C0453947',
#             'mentions': [{'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-03-RESULTS-03'}],
#             'trigger': 'C0205242',
#             'type': 'hyper_edge'},
#            {'arguments': ['C1302275', 'C1419948'],
#             'id': 'C1302275-C1302275-C1419948',
#             'mentions': [{'doc_id': 'PMC2885601-03-RESULTS-03'},
#                          {'doc_id': 'PMC2885601-03-RESULTS-04'},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION'}],
#             'trigger': 'C1302275',
#             'type': 'hyper_edge'},
#            {'id': 'C1621243',
#             'mentions': [{'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'GAS Mac',
#                           'span': {'end': 467, 'start': 460}}],
#             'type': 'entity'},
#            {'id': 'PMC2885601-04-DISCUSSION-T60',
#             'mentions': [{'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'CovRS',
#                           'span': {'end': 2241, 'start': 2236}}],
#             'type': 'entity'},
#            {'id': 'C5419223',
#             'mentions': [{'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'Cleavable',
#                           'span': {'end': 828, 'start': 819}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'cleavable',
#                           'span': {'end': 1088, 'start': 1079}},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION',
#                           'mention': 'cleavable',
#                           'span': {'end': 1088, 'start': 1079}}],
#             'type': 'entity'},
#            {'arguments': ['C0026914', 'PMC2885601-04-DISCUSSION-T60'],
#             'id': 'C2587213-C0026914-PMC2885601-04-DISCUSSION-T60',
#             'mentions': [{'doc_id': 'PMC2885601-04-DISCUSSION'}],
#             'trigger': 'C2587213',
#             'type': 'hyper_edge'},
#            {'arguments': ['C0080178', 'C1621243'],
#             'id': 'C0080178-C0080178-C1621243',
#             'mentions': [{'doc_id': 'PMC2885601-04-DISCUSSION'},
#                          {'doc_id': 'PMC2885601-04-DISCUSSION'}],
#             'trigger': 'C0080178',
#             'type': 'hyper_edge'},
#            {'arguments': ['C1419948', 'C5419223'],
#             'id': 'PMC2885601-04-DISCUSSION-T83-C1419948-C5419223',
#             'mentions': [{'doc_id': 'PMC2885601-04-DISCUSSION'}],
#             'trigger': 'PMC2885601-04-DISCUSSION-T83',
#             'type': 'hyper_edge'},
#            {'arguments': ['C0453947', 'C5419223'],
#             'id': 'PMC2885601-04-DISCUSSION-T83-C0453947-C5419223',
#             'mentions': [{'doc_id': 'PMC2885601-04-DISCUSSION'}],
#             'trigger': 'PMC2885601-04-DISCUSSION-T83',
#             'type': 'hyper_edge'},
#            {'arguments': ['C1419948', 'C5419223'],
#             'id': 'C5419223-C1419948-C5419223',
#             'mentions': [{'doc_id': 'PMC2885601-04-DISCUSSION'}],
#             'trigger': 'C5419223',
#             'type': 'hyper_edge'}]}

# %%
def save_hyper_edges(G, filepath=r'hyper_edges.txt'):
    hyper_edges = [n for n in event_network.nodes() if event_network.nodes[n]['type']=='hyper_edge']
    entities = [n for n in event_network.nodes() if event_network.nodes[n]['type']=='entity']
    # assuming no event-event connection
    node_to_index = {node: i+1 for i, node in enumerate(entities)}
    
    save_json(node_to_index, 'node_to_index.json')
    with open('hyper_edges.txt', 'w', encoding='utf-8') as f:
        for hyper_edge in hyper_edges:
            # assuming no event-event connection
            edge_nodes = [str(node_to_index[n]) for n in G.neighbors(hyper_edge) if event_network.nodes[n]['type']=='entity']
#             edge_nodes = [n for n in G[hyper_edge]]
            
#             if len(edge_nodes) == 1:
#                 pprint(hyper_edge)
#                 pprint([event_network.nodes[n] for n in edge_nodes])

            if len(edge_nodes) > 2:
                print(len(edge_nodes))
            line = ','.join(edge_nodes)
            f.write(line)
            f.write('\n')
    f.close()

# %%
save_hyper_edges(event_network)
# Out:
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 4
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
