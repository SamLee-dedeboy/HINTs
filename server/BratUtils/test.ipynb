# %%
import networkx as nx
import json
from pybrat.parser import BratParser, Entity, Event, Example, Relation
import matplotlib.pyplot as plt
from pprint import pprint
import numpy as np
from collections import defaultdict
import hypernetx as hnx
from networkx.algorithms import bipartite

# %%
def remove_keys(dict, kept_keys):
    return {key: value for key, value in dict.items() if key in kept_keys}

# %%
def read_brat_data(data_path):
    brat = BratParser(error="ignore")
    brat_data = brat.parse(data_path)
    return brat_data

# %%
def disambiguate(brat_data, EL_data_path):
    # assuming no nested events
    nodes_dict = {}
    hyper_edges_dict = {}
    links = []
    connected_nodes = set()
    for doc in brat_data:
        origin_id_to_new_id_dict = {}
        entity_umls = json.load(open(EL_data_path + doc.id + r'.json'))
        # entity disambiguation
        for entity in doc.entities:
            # TODO: add candidate selection. For now just choosing the first one.
            entity_ui = entity.id # reassign node id to either doc_id + original id or CUI
            if len(entity_umls[entity.id]) != 0: 
                entity_ui = entity_umls[entity.id][0]['ui']
            else:
                # TODO: consider partial matching to disambiguiate entities without CUIs
                entity_ui = doc.id + "-" + entity_ui
            origin_id_to_new_id_dict[entity.id] = entity_ui

            if entity_ui not in nodes_dict.keys():
                nodes_dict[entity_ui] = {
                    "id": entity_ui,
                    "type": "entity",
                    "mentions": [
                        {
                            "doc_id": doc.id, 
                            "mention": entity.mention, 
                            "span": {'start': entity.spans[0].start, 'end': entity.spans[0].end}
#                             "span": entity.spans
                        }
                    ],
                }
            else:
                nodes_dict[entity_ui]["mentions"].append(
                    {
                        "doc_id": doc.id, 
                        "mention": entity.mention, 
                        "span": {'start': entity.spans[0].start, 'end': entity.spans[0].end}
                    }
                )
        
        # each event is treated as a hyper-edge. 
        # The hyperedge id needs to be independent, but the node type is trigger id 
        for event in doc.events:
            trigger_id = origin_id_to_new_id_dict[event.trigger.id]
            origin_id_to_new_id_dict[event.id] = trigger_id 
            argument_ids = list(map(lambda argument: origin_id_to_new_id_dict[argument.id], event.arguments))
            connected_nodes.update(argument_ids)
            
            sorted_argument_ids = sorted(argument_ids)
            # create hyper edge node
            hyper_edge_node_id = trigger_id + "-" + "-".join(sorted_argument_ids)

            if hyper_edge_node_id not in hyper_edges_dict.keys():
                hyper_edges_dict[hyper_edge_node_id] = {
                    "id": hyper_edge_node_id,
                    "type": "hyper_edge",
                    "trigger": trigger_id,
                    "arguments": sorted_argument_ids,
                    "mentions": [
                        {
                            "doc_id": doc.id, 
                            # TODO: add sentence span
                            # "mention": entity.mention, 
                            # "span": [entity.spans]
                        }
                    ],
                }
            else:
                hyper_edges_dict[hyper_edge_node_id]["mentions"].append(
                    {
                        "doc_id": doc.id,
                        # TODO: add sentence span
                    }
                )

            # add links between hyper edge node and arguments
            for argument_id in argument_ids:
                links.append((hyper_edge_node_id, argument_id))
#         if doc_count == 10: break
    # clean up un connected nodes
    print(len(nodes_dict), len(hyper_edges_dict), len(links))
    nodes_dict = remove_keys(nodes_dict, kept_keys=connected_nodes)
    print(len(nodes_dict), len(hyper_edges_dict), len(links))
    return nodes_dict, hyper_edges_dict, links

# %%
def merge_brat_data(brat_data, EL_data_path):
    """
    Takes in a list of brat data and merge them into one hypergraph
    """
    nodes_dict, hyper_edges_dict, links = disambiguate(brat_data, EL_data_path) 

    B = nx.Graph()
    B.add_nodes_from(list(nodes_dict.keys()), bipartite=0)
    B.add_nodes_from(list(hyper_edges_dict.keys()), bipartite=1)
    B.add_edges_from(links)
    return hnx.Hypergraph.from_bipartite(B)

# %%
def check_nested_events(brat_data):
    for doc in brat_data:
        entity_ids = [entity.id for entity in doc.entities]
        trigger_ids = [event.trigger for event in doc.events]
        for event in doc.events:
            argument_ids = [argument.id for argument in event.arguments]
            if any([argument_id in trigger_ids for argument_id in argument_ids]):
                print("Nested event found in document: " + doc.id)
                print(argument_ids)
                print(trigger_ids)

# %%
data_path = '../../preprocess/data/result/ID2011/'
brat_data = read_brat_data(data_path)
H = merge_brat_data(brat_data, EL_data_path=data_path)
# Out:
# 4998 2036 3563
# 1232 2036 3563

# %%
# print('1-component edge sets:')
# for comp in H.s_components(s=1):
#     print(comp)

# print('\n2-component edge sets:')
# for comp in H.s_components(s=2):
#     print(comp)
print('\n3-component edge sets:')
for comp in H.s_components(s=3):
    print(comp)
# Out:
# 3-component edge sets:
# {'C0969563', 'C0004482'}
# {'C1701700', 'C0031715'}
# {'C1451978', 'C0038568', 'C1327616', 'C0967543', 'C1433342', 'C0768768', 'C0657653', 'C0961725', 'C1739675', 'C1431905', 'C1429451', 'C5672738', 'C0916739', 'C0042765', 'C0531454', 'C0255025', 'C1441654', 'C0185117'}
# {'C3001658', 'C0086860'}
# {'C1429861', 'C1569547', 'C1449385'}
# {'C2286466', 'C1437563'}
# {'C0003537'}
# {'C0004597'}
# {'C0004599'}
# {'C0006303'}
# {'C0006304'}
# {'C0007018'}
# {'C0008039'}
# {'C0010749'}
# {'C0011522'}
# {'C0012890'}
# {'C0014834'}
# {'C0016228'}
# {'C0017243'}
# {'C0017262'}
# {'C0017861'}
# {'C0019472'}
# {'C0019494'}
# {'C0020835'}
# {'C0020852'}
# {'C0020855'}
# {'C0020859'}
# {'C0020860'}
# {'C0021745'}
# {'C0021756'}
# {'C0022959'}
# {'C0024467'}
# {'C0025646'}
# {'C0026914'}
# {'C0026917'}
# {'C0026926'}
# {'C0027303'}
# {'C0030054'}
# {'C0030894'}
# {'C0032604'}
# {'C0033268'}
# {'C0033373'}
# {'C0033809'}
# {'C0033811'}
# {'C0034579'}
# {'C0034805'}
# {'C0035644'}
# {'C0036106'}
# {'C0036117'}
# {'C0036126'}
# {'C0036766'}
# {'C0037231'}
# {'C0037420'}
# {'C0038172'}
# {'C0038402'}
# {'C0038404'}
# {'C0038410'}
# {'C0038411'}
# {'C0038418'}
# {'C0040649'}
# {'C0041296'}
# {'C0042629'}
# {'C0042845'}
# {'C0043408'}
# {'C0043409'}
# {'C0052656'}
# {'C0053697'}
# {'C0054988'}
# {'C0056020'}
# {'C0056207'}
# {'C0056301'}
# {'C0060610'}
# {'C0061906'}
# {'C0074995'}
# {'C0075292'}
# {'C0075301'}
# {'C0075302'}
# {'C0076791'}
# {'C0079488'}
# {'C0079633'}
# {'C0080178'}
# {'C0082938'}
# {'C0083273'}
# {'C0085470'}
# {'C0085485'}
# {'C0085489'}
# {'C0085520'}
# {'C0085957'}
# {'C0090284'}
# {'C0102137'}
# {'C0109284'}
# {'C0119687'}
# {'C0141444'}
# {'C0162610'}
# {'C0162809'}
# {'C0163475'}
# {'C0168586'}
# {'C0171334'}
# {'C0175697'}
# {'C0185023'}
# {'C0205216'}
# {'C0205217'}
# {'C0205242'}
# {'C0205263'}
# {'C0205339'}
# {'C0210371'}
# {'C0216127'}
# {'C0220669'}
# {'C0230927'}
# {'C0243125'}
# {'C0244036'}
# {'C0244098'}
# {'C0245425'}
# {'C0250225'}
# {'C0255273'}
# {'C0255766'}
# {'C0256158'}
# {'C0262755'}
# {'C0265216'}
# {'C0276180'}
# {'C0283878'}
# {'C0289536'}
# {'C0294175'}
# {'C0295181'}
# {'C0297551'}
# {'C0317454'}
# {'C0318157'}
# {'C0318171'}
# {'C0332161'}
# {'C0332297'}
# {'C0332325'}
# {'C0336892'}
# {'C0348055'}
# {'C0367378'}
# {'C0376495'}
# {'C0380349'}
# {'C0382677'}
# {'C0383704'}
# {'C0385732'}
# {'C0386638'}
# {'C0441889'}
# {'C0445671'}
# {'C0445750'}
# {'C0453947'}
# {'C0454277'}
# {'C0455990'}
# {'C0458343'}
# {'C0470256'}
# {'C0522506'}
# {'C0524654'}
# {'C0525522'}
# {'C0532038'}
# {'C0533821'}
# {'C0544461'}
# {'C0560137'}
# {'C0561878'}
# {'C0579230'}
# {'C0579233'}
# {'C0618319'}
# {'C0619468'}
# {'C0642014'}
# {'C0647714'}
# {'C0656135'}
# {'C0660482'}
# {'C0661295'}
# {'C0663199'}
# {'C0664254'}
# {'C0665221'}
# {'C0668201'}
# {'C0672103'}
# {'C0673634'}
# {'C0674722'}
# {'C0683598'}
# {'C0700271'}
# {'C0700842'}
# {'C0718617'}
# {'C0721374'}
# {'C0752042'}
# {'C0752043'}
# {'C0754686'}
# {'C0755857'}
# {'C0761087'}
# {'C0765969'}
# {'C0803300'}
# {'C0812211'}
# {'C0812445'}
# {'C0851285'}
# {'C0857127'}
# {'C0868946'}
# {'C0880410'}
# {'C0880426'}
# {'C0880832'}
# {'C0881028'}
# {'C0893533'}
# {'C0893581'}
# {'C0893599'}
# {'C0893600'}
# {'C0907916'}
# {'C0912510'}
# {'C0914313'}
# {'C0919282'}
# {'C0919293'}
# {'C0961154'}
# {'C0962033'}
# {'C0962034'}
# {'C0962697'}
# {'C0965005'}
# {'C0965285'}
# {'C0965349'}
# {'C0967087'}
# {'C0968261'}
# {'C0968595'}
# {'C0969110'}
# {'C0971167'}
# {'C1003179'}
# {'C1006457'}
# {'C1011526'}
# {'C1062752'}
# {'C1063594'}
# {'C1099227'}
# {'C1100846'}
# {'C1101557'}
# {'C1120479'}
# {'C1121186'}
# {'C1136789'}
# {'C1137089'}
# {'C1137167'}
# {'C1140704'}
# {'C1141646'}
# {'C1142748'}
# {'C1145667'}
# {'C1149341'}
# {'C1149405'}
# {'C1149789'}
# {'C1150124'}
# {'C1150819'}
# {'C1150833'}
# {'C1152228'}
# {'C1158770'}
# {'C1171362'}
# {'C1172332'}
# {'C1174335'}
# {'C1174336'}
# {'C1198396'}
# {'C1256919'}
# {'C1257040'}
# {'C1257144'}
# {'C1257195'}
# {'C1257396'}
# {'C1257418'}
# {'C1257420'}
# {'C1258335'}
# {'C1258716'}
# {'C1258717'}
# {'C1265175'}
# {'C1302275'}
# {'C1307044'}
# {'C1307335'}
# {'C1310139'}
# {'C1312520'}
# {'C1312829'}
# {'C1313086'}
# {'C1316885'}
# {'C1323338'}
# {'C1323631'}
# {'C1327142'}
# {'C1333696'}
# {'C1336661'}
# {'C1394210'}
# {'C1412591'}
# {'C1412625'}
# {'C1412751'}
# {'C1413106'}
# {'C1413504'}
# {'C1413716'}
# {'C1414063'}
# {'C1416602'}
# {'C1416780'}
# {'C1417209'}
# {'C1417375'}
# {'C1419209'}
# {'C1419301'}
# {'C1419948'}
# {'C1422345'}
# {'C1429459'}
# {'C1429597'}
# {'C1429662'}
# {'C1429666'}
# {'C1429706'}
# {'C1429853'}
# {'C1430105'}
# {'C1430113'}
# {'C1430469'}
# {'C1430557'}
# {'C1431179'}
# {'C1431735'}
# {'C1431904'}
# {'C1431954'}
# {'C1431995'}
# {'C1432414'}
# {'C1433573'}
# {'C1433682'}
# {'C1434520'}
# {'C1435918'}
# {'C1436594'}
# {'C1437295'}
# {'C1437317'}
# {'C1437334'}
# {'C1437347'}
# {'C1437396'}
# {'C1437425'}
# {'C1437464'}
# {'C1437584'}
# {'C1437599'}
# {'C1437623'}
# {'C1437647'}
# {'C1437656'}
# {'C1437665'}
# {'C1437732'}
# {'C1437738'}
# {'C1437841'}
# {'C1438658'}
# {'C1438969'}
# {'C1442099'}
# {'C1443158'}
# {'C1447038'}
# {'C1447255'}
# {'C1447300'}
# {'C1447365'}
# {'C1447903'}
# {'C1448311'}
# {'C1448612'}
# {'C1448805'}
# {'C1448889'}
# {'C1449831'}
# {'C1453397'}
# {'C1453542'}
# {'C1453882'}
# {'C1455032'}
# {'C1455327'}
# {'C1455641'}
# {'C1479218'}
# {'C1485788'}
# {'C1504637'}
# {'C1505214'}
# {'C1505298'}
# {'C1505783'}
# {'C1506694'}
# {'C1507687'}
# {'C1520022'}
# {'C1529788'}
# {'C1530783'}
# {'C1541907'}
# {'C1549519'}
# {'C1550641'}
# {'C1552648'}
# {'C1565866'}
# {'C1566707'}
# {'C1568028'}
# {'C1569102'}
# {'C1570344'}
# {'C1570920'}
# {'C1571328'}
# {'C1571329'}
# {'C1609962'}
# {'C1611321'}
# {'C1613871'}
# {'C1621243'}
# {'C1622426'}
# {'C1622789'}
# {'C1623416'}
# {'C1637351'}
# {'C1640221'}
# {'C1656840'}
# {'C1673279'}
# {'C1702028'}
# {'C1704492'}
# {'C1706428'}
# {'C1722214'}
# {'C1741167'}
# {'C1741620'}
# {'C1741793'}
# {'C1744314'}
# {'C1817202'}
# {'C1824728'}
# {'C1824754'}
# {'C1825375'}
# {'C1825552'}
# {'C1827066'}
# {'C1857351'}
# {'C1870620'}
# {'C1879547'}
# {'C1903696'}
# {'C1906688'}
# {'C1909997'}
# {'C1955824'}
# {'C1956708'}
# {'C1999470'}
# {'C1999838'}
# {'C2001849'}
# {'C2039216'}
# {'C2247059'}
# {'C2296470'}
# {'C2351480'}
# {'C2607517'}
# {'C2669106'}
# {'C2732827'}
# {'C2742851'}
# {'C2742852'}
# {'C2743287'}
# {'C2744603'}
# {'C2830138'}
# {'C2932215'}
# {'C2932673'}
# {'C2933417'}
# {'C2936173'}
# {'C2966800'}
# {'C2975767'}
# {'C2976703'}
# {'C3180211'}
# {'C3180684'}
# {'C3180783'}
# {'C3245525'}
# {'C3252021'}
# {'C3252346'}
# {'C3252979'}
# {'C3254480'}
# {'C3254731'}
# {'C3305611'}
# {'C3365966'}
# {'C3366001'}
# {'C3492936'}
# {'C3546523'}
# {'C3659907'}
# {'C3663567'}
# {'C3714514'}
# {'C3715633'}
# {'C3771099'}
# {'C3773040'}
# {'C3824251'}
# {'C3886631'}
# {'C3887572'}
# {'C3891304'}
# {'C3921563'}
# {'C3964964'}
# {'C4037692'}
# {'C4037697'}
# {'C4053901'}
# {'C4071452'}
# {'C4076761'}
# {'C4078748'}
# {'C4094263'}
# {'C4114481'}
# {'C4278777'}
# {'C4307955'}
# {'C4309666'}
# {'C4339495'}
# {'C4394366'}
# {'C4400529'}
# {'C4483126'}
# {'C4505328'}
# {'C4507377'}
# {'C4507843'}
# {'C4527497'}
# {'C4532605'}
# {'C4547159'}
# {'C4548191'}
# {'C4559850'}
# {'C4689671'}
# {'C4689703'}
# {'C4699302'}
# {'C4722709'}
# {'C4742986'}
# {'C4777484'}
# {'C5086777'}
# {'C5125333'}
# {'C5197139'}
# {'C5197502'}
# {'C5212642'}
# {'C5226174'}
# {'C5226344'}
# {'C5226623'}
# {'C5238961'}
# {'C5238963'}
# {'C5285159'}
# {'C5301858'}
# {'C5373037'}
# {'C5392446'}
# {'C5419223'}
# {'C5476691'}
# {'C5540384'}
# {'C5543850'}
# {'C5556768'}
# {'C5564820'}
# {'C5573979'}
# {'PMC1475658-00-TIAB-T3'}
# {'PMC1475658-00-TIAB-T4'}
# {'PMC1475658-01-Introduction-T26'}
# {'PMC1475658-01-Introduction-T37'}
# {'PMC1475658-02-Results-01-T27'}
# {'PMC1475658-02-Results-01-T4'}
# {'PMC1475658-02-Results-02-T21'}
# {'PMC1475658-02-Results-02-T22'}
# {'PMC1475658-02-Results-02-T24'}
# {'PMC1475658-02-Results-02-T25'}
# {'PMC1475658-02-Results-02-T29'}
# {'PMC1475658-02-Results-02-T33'}
# {'PMC1475658-02-Results-02-T38'}
# {'PMC1475658-02-Results-02-T4'}
# {'PMC1475658-02-Results-02-T46'}
# {'PMC1475658-02-Results-02-T57'}
# {'PMC1475658-02-Results-03-T12'}
# {'PMC1475658-02-Results-03-T14'}
# {'PMC1475658-02-Results-03-T17'}
# {'PMC1475658-02-Results-03-T28'}
# {'PMC1475658-02-Results-03-T3'}
# {'PMC1913099-02-Results-Discussion-05-T3'}
# {'PMC1913099-02-Results-Discussion-06-T13'}
# {'PMC1913099-02-Results-Discussion-08-T24'}
# {'PMC1913099-02-Results-Discussion-08-T25'}
# {'PMC1913099-02-Results-Discussion-09-T8'}
# {'PMC1913099-02-Results-Discussion-10-T10'}
# {'PMC1913099-02-Results-Discussion-10-T11'}
# {'PMC1913099-02-Results-Discussion-10-T16'}
# {'PMC1913099-02-Results-Discussion-11-T2'}
# {'PMC1913099-02-Results-Discussion-13-T11'}
# {'PMC1913099-02-Results-Discussion-13-T8'}
# {'PMC1974823-00-TIAB-T9'}
# {'PMC1974823-01-Introduction-T29'}
# {'PMC1974823-01-Introduction-T31'}
# {'PMC1974823-01-Introduction-T72'}
# {'PMC1974823-03-Results-01-T25'}
# {'PMC1974823-03-Results-01-T30'}
# {'PMC1974823-03-Results-01-T32'}
# {'PMC1974823-03-Results-01-T4'}
# {'PMC1974823-03-Results-01-T56'}
# {'PMC1974823-03-Results-03-T19'}
# {'PMC1974823-03-Results-03-T21'}
# {'PMC1974823-03-Results-03-T24'}
# {'PMC1974823-03-Results-03-T29'}
# {'PMC1974823-03-Results-03-T34'}
# {'PMC1974823-03-Results-03-T41'}
# {'PMC1974823-03-Results-03-T42'}
# {'PMC1974823-03-Results-03-T43'}
# {'PMC1974823-03-Results-03-T56'}
# {'PMC1974823-04-Discussion-T15'}
# {'PMC1974823-04-Discussion-T38'}
# {'PMC1974823-04-Discussion-T4'}
# {'PMC1974823-04-Discussion-T60'}
# {'PMC1974823-04-Discussion-T62'}
# {'PMC1974823-04-Discussion-T7'}
# {'PMC1974823-04-Discussion-T74'}
# {'PMC1974823-04-Discussion-T78'}
# {'PMC1976333-02-Results-Discussion-03-T11'}
# {'PMC1976333-02-Results-Discussion-06-T45'}
# {'PMC1976333-02-Results-Discussion-06-T49'}
# {'PMC1976333-02-Results-Discussion-06-T51'}
# {'PMC1976333-02-Results-Discussion-06-T53'}
# {'PMC1976333-02-Results-Discussion-07-T47'}
# {'PMC1976333-02-Results-Discussion-07-T72'}
# {'PMC1976333-02-Results-Discussion-08-T10'}
# {'PMC1976333-02-Results-Discussion-08-T12'}
# {'PMC1976333-02-Results-Discussion-09-T16'}
# {'PMC1976333-02-Results-Discussion-09-T26'}
# {'PMC1976333-02-Results-Discussion-10-T49'}
# {'PMC1976333-02-Results-Discussion-10-T54'}
# {'PMC1976333-02-Results-Discussion-12-T24'}
# {'PMC2242835-00-TIAB-T17'}
# {'PMC2242835-00-TIAB-T4'}
# {'PMC2242835-00-TIAB-T7'}
# {'PMC2242835-01-Introduction-T17'}
# {'PMC2242835-01-Introduction-T22'}
# {'PMC2242835-02-Results-03-T1'}
# {'PMC2242835-02-Results-03-T14'}
# {'PMC2242835-02-Results-03-T2'}
# {'PMC2242835-02-Results-04-T16'}
# {'PMC2242835-02-Results-04-T2'}
# {'PMC2242835-02-Results-04-T6'}
# {'PMC2242835-02-Results-04-T8'}
# {'PMC2242835-02-Results-04-T9'}
# {'PMC2266911-02-Results_and_Discussion-02-02-T23'}
# {'PMC2266911-02-Results_and_Discussion-02-02-T31'}
# {'PMC2266911-02-Results_and_Discussion-02-04-T10'}
# {'PMC2266911-02-Results_and_Discussion-02-04-T2'}
# {'PMC2266911-02-Results_and_Discussion-03-02-T41'}
# {'PMC2266911-02-Results_and_Discussion-03-02-T43'}
# {'PMC2266911-02-Results_and_Discussion-03-02-T45'}
# {'PMC2266911-02-Results_and_Discussion-03-02-T47'}
# {'PMC2266911-02-Results_and_Discussion-03-02-T50'}
# {'PMC2266911-02-Results_and_Discussion-03-02-T52'}
# {'PMC2266911-02-Results_and_Discussion-03-02-T69'}
# {'PMC2266911-02-Results_and_Discussion-03-03-T20'}
# {'PMC2266911-02-Results_and_Discussion-03-03-T36'}
# {'PMC2266911-02-Results_and_Discussion-04-T7'}
# {'PMC2358977-00-TIAB-T4'}
# {'PMC2358977-01-Introduction-T5'}
# {'PMC2358977-02-Results-04-T13'}
# {'PMC2358977-02-Results-04-T16'}
# {'PMC2358977-02-Results-04-T2'}
# {'PMC2358977-02-Results-04-T27'}
# {'PMC2358977-02-Results-04-T7'}
# {'PMC2358977-02-Results-05-T1'}
# {'PMC2358977-02-Results-05-T6'}
# {'PMC2358977-02-Results-06-01-T10'}
# {'PMC2358977-02-Results-06-02-T4'}
# {'PMC2358977-02-Results-06-02-T5'}
# {'PMC2358977-02-Results-06-02-T8'}
# {'PMC2358977-02-Results-06-03-T1'}
# {'PMC2358977-02-Results-06-03-T2'}
# {'PMC2358977-03-Discussion-T14'}
# {'PMC2358977-03-Discussion-T39'}
# {'PMC2358977-03-Discussion-T40'}
# {'PMC2358977-03-Discussion-T43'}
# {'PMC2430206-00-TIAB-T11'}
# {'PMC2430206-00-TIAB-T13'}
# {'PMC2430206-01-Background-T11'}
# {'PMC2430206-01-Background-T13'}
# {'PMC2430206-01-Background-T19'}
# {'PMC2430206-02-Results-01-T10'}
# {'PMC2430206-02-Results-01-T12'}
# {'PMC2430206-02-Results-01-T20'}
# {'PMC2430206-02-Results-01-T23'}
# {'PMC2430206-02-Results-01-T31'}
# {'PMC2430206-02-Results-01-T42'}
# {'PMC2430206-02-Results-01-T61'}
# {'PMC2430206-02-Results-01-T7'}
# {'PMC2430206-02-Results-01-T9'}
# {'PMC2430206-02-Results-02-T11'}
# {'PMC2430206-02-Results-02-T4'}
# {'PMC2430206-02-Results-02-T9'}
# {'PMC2530867-01-Background-T14'}
# {'PMC2530867-02-Results_and_discussion-08-T37'}
# {'PMC2530867-02-Results_and_discussion-11-T16'}
# {'PMC2530867-02-Results_and_discussion-11-T17'}
# {'PMC2565068-00-TIAB-T14'}
# {'PMC2565068-01-Introduction-T15'}
# {'PMC2565068-01-Introduction-T22'}
# {'PMC2565068-01-Introduction-T33'}
# {'PMC2565068-02-Results-01-T4'}
# {'PMC2565068-02-Results-04-T34'}
# {'PMC2565068-02-Results-06-T22'}
# {'PMC2565068-02-Results-06-T34'}
# {'PMC2565068-02-Results-06-T37'}
# {'PMC2605554-01-Introduction-T28'}
# {'PMC2605554-01-Introduction-T35'}
# {'PMC2605554-01-Introduction-T38'}
# {'PMC2605554-01-Introduction-T41'}
# {'PMC2605554-03-Results-04-T19'}
# {'PMC2605554-03-Results-04-T5'}
# {'PMC2605554-03-Results-06-T4'}
# {'PMC2639726-00-TIAB-T4'}
# {'PMC2639726-02-Results-01-T39'}
# {'PMC2639726-02-Results-07-T12'}
# {'PMC2639726-02-Results-07-T14'}
# {'PMC2639726-02-Results-07-T5'}
# {'PMC2639726-02-Results-07-T9'}
# {'PMC2639726-02-Results-08-T54'}
# {'PMC2639726-02-Results-08-T57'}
# {'PMC2639726-02-Results-08-T60'}
# {'PMC2639726-03-Discussion-01-T49'}
# {'PMC2639726-03-Discussion-01-T60'}
# {'PMC2639726-03-Discussion-03-T39'}
# {'PMC2639726-03-Discussion-03-T41'}
# {'PMC2651894-00-TIAB-T6'}
# {'PMC2651894-02-Results-01-T25'}
# {'PMC2651894-02-Results-01-T48'}
# {'PMC2651894-02-Results-01-T50'}
# {'PMC2651894-02-Results-01-T52'}
# {'PMC2651894-03-Discussion-T27'}
# {'PMC2651894-03-Discussion-T30'}
# {'PMC2651894-03-Discussion-T34'}
# {'PMC2651894-03-Discussion-T35'}
# {'PMC2651894-03-Discussion-T42'}
# {'PMC2652828-01-Introduction-T18'}
# {'PMC2652828-01-Introduction-T27'}
# {'PMC2652828-02-Results_and_Discussion-02-T1'}
# {'PMC2652828-02-Results_and_Discussion-02-T14'}
# {'PMC2652828-02-Results_and_Discussion-02-T16'}
# {'PMC2652828-02-Results_and_Discussion-02-T17'}
# {'PMC2652828-02-Results_and_Discussion-02-T18'}
# {'PMC2652828-02-Results_and_Discussion-02-T19'}
# {'PMC2652828-02-Results_and_Discussion-02-T2'}
# {'PMC2652828-02-Results_and_Discussion-02-T3'}
# {'PMC2652828-02-Results_and_Discussion-02-T8'}
# {'PMC2652828-02-Results_and_Discussion-02-T9'}
# {'PMC2652828-02-Results_and_Discussion-04-T46'}
# {'PMC2652828-02-Results_and_Discussion-04-T60'}
# {'PMC2652828-02-Results_and_Discussion-05-01-T10'}
# {'PMC2652828-02-Results_and_Discussion-05-01-T13'}
# {'PMC2652828-02-Results_and_Discussion-05-01-T8'}
# {'PMC2652828-02-Results_and_Discussion-05-01-T9'}
# {'PMC2652828-02-Results_and_Discussion-05-02-T17'}
# {'PMC2652828-02-Results_and_Discussion-05-02-T4'}
# {'PMC2652828-02-Results_and_Discussion-05-05-T17'}
# {'PMC2652828-02-Results_and_Discussion-05-05-T18'}
# {'PMC2652828-02-Results_and_Discussion-05-05-T20'}
# {'PMC2652828-02-Results_and_Discussion-05-05-T46'}
# {'PMC2652828-02-Results_and_Discussion-07-T26'}
# {'PMC2652828-02-Results_and_Discussion-07-T27'}
# {'PMC2682197-00-TIAB-T12'}
# {'PMC2682197-02-Results-01-T13'}
# {'PMC2682197-02-Results-01-T5'}
# {'PMC2682197-02-Results-02-T12'}
# {'PMC2682197-02-Results-02-T13'}
# {'PMC2760582-03-Discussion-03-T9'}
# {'PMC2760582-03-Discussion-04-T12'}
# {'PMC2760582-03-Discussion-04-T24'}
# {'PMC2760582-03-Discussion-04-T25'}
# {'PMC2760582-03-Discussion-05-T24'}
# {'PMC2760582-03-Discussion-05-T3'}
# {'PMC2760582-03-Discussion-05-T32'}
# {'PMC2760582-03-Discussion-05-T34'}
# {'PMC2760582-03-Discussion-05-T8'}
# {'PMC2760582-03-Discussion-05-T9'}
# {'PMC2760582-03-Discussion-06-T34'}
# {'PMC2760582-03-Discussion-06-T35'}
# {'PMC2760582-03-Discussion-06-T36'}
# {'PMC2760582-03-Discussion-07-T1'}
# {'PMC2760582-04-Conclusion-T4'}
# {'PMC2760582-04-Conclusion-T7'}
# {'PMC2774163-00-TIAB-T19'}
# {'PMC2774163-00-TIAB-T22'}
# {'PMC2774163-01-Introduction-T36'}
# {'PMC2774163-02-Results-02-T12'}
# {'PMC2774163-02-Results-02-T13'}
# {'PMC2774163-02-Results-02-T15'}
# {'PMC2774163-02-Results-02-T19'}
# {'PMC2774163-02-Results-02-T2'}
# {'PMC2774163-02-Results-02-T20'}
# {'PMC2774163-02-Results-02-T25'}
# {'PMC2774163-02-Results-02-T26'}
# {'PMC2774163-02-Results-02-T30'}
# {'PMC2774163-02-Results-02-T32'}
# {'PMC2774163-02-Results-02-T33'}
# {'PMC2774163-02-Results-02-T35'}
# {'PMC2774163-02-Results-02-T36'}
# {'PMC2774163-02-Results-02-T37'}
# {'PMC2774163-02-Results-02-T38'}
# {'PMC2774163-02-Results-02-T39'}
# {'PMC2774163-02-Results-02-T4'}
# {'PMC2774163-02-Results-02-T40'}
# {'PMC2774163-02-Results-02-T42'}
# {'PMC2774163-02-Results-02-T6'}
# {'PMC2774163-02-Results-02-T7'}
# {'PMC2774163-02-Results-02-T9'}
# {'PMC2774163-02-Results-03-T2'}
# {'PMC2774163-02-Results-03-T3'}
# {'PMC2774163-02-Results-03-T32'}
# {'PMC2774163-02-Results-03-T38'}
# {'PMC2774163-02-Results-03-T4'}
# {'PMC2774163-02-Results-03-T40'}
# {'PMC2774163-02-Results-03-T44'}
# {'PMC2774163-02-Results-03-T46'}
# {'PMC2774163-02-Results-04-T13'}
# {'PMC2774163-02-Results-04-T21'}
# {'PMC2774163-02-Results-04-T3'}
# {'PMC2774163-02-Results-07-T15'}
# {'PMC2774163-02-Results-07-T2'}
# {'PMC2774163-03-Discussion-T113'}
# {'PMC2774163-03-Discussion-T54'}
# {'PMC2774163-03-Discussion-T74'}
# {'PMC2816692-00-TIAB-T14'}
# {'PMC2816692-00-TIAB-T16'}
# {'PMC2816692-01-Introduction-T28'}
# {'PMC2816692-01-Introduction-T34'}
# {'PMC2816692-02-Results-01-T21'}
# {'PMC2816692-02-Results-01-T5'}
# {'PMC2816692-02-Results-02-T25'}
# {'PMC2816692-02-Results-03-T24'}
# {'PMC2816692-02-Results-04-T20'}
# {'PMC2816692-02-Results-04-T23'}
# {'PMC2816692-02-Results-04-T6'}
# {'PMC2829055-02-Results-Discussion-05-T33'}
# {'PMC2829055-02-Results-Discussion-06-T20'}
# {'PMC2837388-02-Results-03-T14'}
# {'PMC2837388-02-Results-07-T41'}
# {'PMC2837388-02-Results-07-T48'}
# {'PMC2837388-03-Discussion-T35'}
# {'PMC2854683-00-TIAB-T14'}
# {'PMC2854683-00-TIAB-T2'}
# {'PMC2854683-00-TIAB-T9'}
# {'PMC2854683-01-Introduction-T30'}
# {'PMC2854683-01-Introduction-T46'}
# {'PMC2854683-01-Introduction-T51'}
# {'PMC2854683-03-Discussion-02-T49'}
# {'PMC2854683-03-Discussion-02-T8'}
# {'PMC2856668-00-TIAB-T1'}
# {'PMC2856668-00-TIAB-T10'}
# {'PMC2856668-00-TIAB-T16'}
# {'PMC2856668-00-TIAB-T9'}
# {'PMC2856668-01-Introduction-T30'}
# {'PMC2856668-01-Introduction-T33'}
# {'PMC2856668-01-Introduction-T37'}
# {'PMC2856668-01-Introduction-T47'}
# {'PMC2856668-01-Introduction-T52'}
# {'PMC2856668-01-Introduction-T57'}
# {'PMC2856668-03-Results-01-T6'}
# {'PMC2856668-03-Results-02-T18'}
# {'PMC2856668-03-Results-02-T23'}
# {'PMC2856668-03-Results-05-T10'}
# {'PMC2856668-04-Discussion-T102'}
# {'PMC2856668-04-Discussion-T12'}
# {'PMC2856668-04-Discussion-T136'}
# {'PMC2856668-04-Discussion-T137'}
# {'PMC2856668-04-Discussion-T24'}
# {'PMC2856668-04-Discussion-T25'}
# {'PMC2856668-04-Discussion-T38'}
# {'PMC2856668-04-Discussion-T5'}
# {'PMC2856668-04-Discussion-T57'}
# {'PMC2856668-04-Discussion-T93'}
# {'PMC2858072-00-TIAB-T18'}
# {'PMC2858072-00-TIAB-T19'}
# {'PMC2858072-00-TIAB-T23'}
# {'PMC2858072-00-TIAB-T24'}
# {'PMC2858072-00-TIAB-T27'}
# {'PMC2858072-00-TIAB-T29'}
# {'PMC2858072-00-TIAB-T30'}
# {'PMC2858072-00-TIAB-T6'}
# {'PMC2858072-01-Introduction-T15'}
# {'PMC2858072-01-Introduction-T19'}
# {'PMC2858072-01-Introduction-T30'}
# {'PMC2858072-01-Introduction-T34'}
# {'PMC2858072-02-Results_and_Discussion-01-T27'}
# {'PMC2858072-02-Results_and_Discussion-01-T33'}
# {'PMC2858072-02-Results_and_Discussion-01-T35'}
# {'PMC2858072-02-Results_and_Discussion-01-T38'}
# {'PMC2858072-02-Results_and_Discussion-01-T39'}
# {'PMC2858072-02-Results_and_Discussion-01-T40'}
# {'PMC2858072-02-Results_and_Discussion-01-T43'}
# {'PMC2858072-02-Results_and_Discussion-01-T46'}
# {'PMC2858072-02-Results_and_Discussion-01-T60'}
# {'PMC2858072-02-Results_and_Discussion-01-T62'}
# {'PMC2858072-02-Results_and_Discussion-01-T65'}
# {'PMC2858072-02-Results_and_Discussion-01-T66'}
# {'PMC2858072-02-Results_and_Discussion-01-T67'}
# {'PMC2858072-02-Results_and_Discussion-01-T68'}
# {'PMC2858072-02-Results_and_Discussion-01-T69'}
# {'PMC2858072-02-Results_and_Discussion-01-T76'}
# {'PMC2858072-02-Results_and_Discussion-01-T77'}
# {'PMC2858072-02-Results_and_Discussion-01-T78'}
# {'PMC2858072-02-Results_and_Discussion-02-T103'}
# {'PMC2858072-02-Results_and_Discussion-02-T112'}
# {'PMC2858072-02-Results_and_Discussion-02-T121'}
# {'PMC2858072-02-Results_and_Discussion-02-T128'}
# {'PMC2858072-02-Results_and_Discussion-02-T131'}
# {'PMC2858072-02-Results_and_Discussion-02-T133'}
# {'PMC2858072-02-Results_and_Discussion-02-T44'}
# {'PMC2858072-02-Results_and_Discussion-02-T69'}
# {'PMC2858072-02-Results_and_Discussion-02-T75'}
# {'PMC2858072-02-Results_and_Discussion-02-T77'}
# {'PMC2858072-02-Results_and_Discussion-02-T78'}
# {'PMC2858072-02-Results_and_Discussion-03-T10'}
# {'PMC2858072-02-Results_and_Discussion-03-T108'}
# {'PMC2858072-02-Results_and_Discussion-03-T12'}
# {'PMC2858072-02-Results_and_Discussion-03-T14'}
# {'PMC2858072-02-Results_and_Discussion-03-T15'}
# {'PMC2858072-02-Results_and_Discussion-03-T18'}
# {'PMC2858072-02-Results_and_Discussion-03-T20'}
# {'PMC2858072-02-Results_and_Discussion-03-T23'}
# {'PMC2858072-02-Results_and_Discussion-03-T25'}
# {'PMC2858072-02-Results_and_Discussion-03-T27'}
# {'PMC2858072-02-Results_and_Discussion-03-T28'}
# {'PMC2858072-02-Results_and_Discussion-03-T30'}
# {'PMC2858072-02-Results_and_Discussion-03-T32'}
# {'PMC2858072-02-Results_and_Discussion-03-T39'}
# {'PMC2858072-02-Results_and_Discussion-03-T49'}
# {'PMC2858072-02-Results_and_Discussion-03-T6'}
# {'PMC2858072-02-Results_and_Discussion-03-T7'}
# {'PMC2858072-02-Results_and_Discussion-03-T77'}
# {'PMC2858072-02-Results_and_Discussion-03-T9'}
# {'PMC2858072-02-Results_and_Discussion-03-T92'}
# {'PMC2858072-02-Results_and_Discussion-04-T26'}
# {'PMC2858072-02-Results_and_Discussion-04-T28'}
# {'PMC2858072-02-Results_and_Discussion-04-T3'}
# {'PMC2858072-02-Results_and_Discussion-04-T30'}
# {'PMC2858072-02-Results_and_Discussion-04-T40'}
# {'PMC2858072-02-Results_and_Discussion-04-T44'}
# {'PMC2858072-02-Results_and_Discussion-04-T55'}
# {'PMC2858072-02-Results_and_Discussion-04-T60'}
# {'PMC2858072-02-Results_and_Discussion-04-T63'}
# {'PMC2858072-02-Results_and_Discussion-04-T64'}
# {'PMC2858072-02-Results_and_Discussion-04-T65'}
# {'PMC2858072-02-Results_and_Discussion-04-T66'}
# {'PMC2858072-02-Results_and_Discussion-04-T68'}
# {'PMC2858072-02-Results_and_Discussion-04-T70'}
# {'PMC2858072-02-Results_and_Discussion-04-T71'}
# {'PMC2885601-03-RESULTS-03-T14'}
# {'PMC2885601-03-RESULTS-03-T15'}
# {'PMC2885601-03-RESULTS-03-T16'}
# {'PMC2885601-04-DISCUSSION-T60'}
